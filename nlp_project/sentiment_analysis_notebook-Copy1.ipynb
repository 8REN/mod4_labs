# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#functions" data-toc-modified-id="functions-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>functions</a></span></li></ul></li><li><span><a href="#Obtain-data" data-toc-modified-id="Obtain-data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Obtain data</a></span></li><li><span><a href="#Scrub-data" data-toc-modified-id="Scrub-data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Scrub data</a></span><ul class="toc-item"><li><span><a href="#missing-data" data-toc-modified-id="missing-data-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>missing data</a></span><ul class="toc-item"><li><span><a href="#missing-tweet-data" data-toc-modified-id="missing-tweet-data-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>missing tweet data</a></span></li><li><span><a href="#missing-product-data" data-toc-modified-id="missing-product-data-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>missing product data</a></span></li></ul></li><li><span><a href="#remove-twitter-handles-from-tweet-text" data-toc-modified-id="remove-twitter-handles-from-tweet-text-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>remove twitter handles from tweet text</a></span></li><li><span><a href="#create-hashtag-column" data-toc-modified-id="create-hashtag-column-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>create hashtag column</a></span></li><li><span><a href="#clean-tweet-text" data-toc-modified-id="clean-tweet-text-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>clean tweet text</a></span></li></ul></li><li><span><a href="#sentiment-column-clean-up" data-toc-modified-id="sentiment-column-clean-up-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>sentiment column clean up</a></span></li><li><span><a href="#Explore" data-toc-modified-id="Explore-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Explore</a></span></li><li><span><a href="#More-Scrubbing" data-toc-modified-id="More-Scrubbing-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>More Scrubbing</a></span><ul class="toc-item"><li><span><a href="#stopwords-assessment-and-removal" data-toc-modified-id="stopwords-assessment-and-removal-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>stopwords assessment and removal</a></span></li><li><span><a href="#tokenize,-lemmatize,-stemming" data-toc-modified-id="tokenize,-lemmatize,-stemming-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>tokenize, lemmatize, stemming</a></span></li></ul></li><li><span><a href="#further-exploration-of-only-positive-and-negative-sentiment" data-toc-modified-id="further-exploration-of-only-positive-and-negative-sentiment-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>further exploration of only positive and negative sentiment</a></span><ul class="toc-item"><li><span><a href="#of-only-positive-and-negative-sentiment" data-toc-modified-id="of-only-positive-and-negative-sentiment-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>of only positive and negative sentiment</a></span></li><li><span><a href="#assess-word-frequency" data-toc-modified-id="assess-word-frequency-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>assess word frequency</a></span></li></ul></li><li><span><a href="#model" data-toc-modified-id="model-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>model</a></span><ul class="toc-item"><li><span><a href="#functions" data-toc-modified-id="functions-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>functions</a></span></li><li><span><a href="#PCA-data-visualization" data-toc-modified-id="PCA-data-visualization-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>PCA data visualization</a></span></li><li><span><a href="#transform-data-from-strings-to-numeric-data" data-toc-modified-id="transform-data-from-strings-to-numeric-data-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>transform data from strings to numeric data</a></span></li></ul></li><li><span><a href="#initially-i-transformed-my-data-before-the-train-test-split,-these-are-the-results" data-toc-modified-id="initially-i-transformed-my-data-before-the-train-test-split,-these-are-the-results-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>initially i transformed my data before the train test split, these are the results</a></span><ul class="toc-item"><li><span><a href="#prepare-data-for-model" data-toc-modified-id="prepare-data-for-model-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>prepare data for model</a></span></li><li><span><a href="#apply-smote-to-target-data-due-to-unbalanced-data" data-toc-modified-id="apply-smote-to-target-data-due-to-unbalanced-data-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>apply smote to target data due to unbalanced data</a></span></li><li><span><a href="#nn-model-#1" data-toc-modified-id="nn-model-#1-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span><del>nn model #1</del></a></span><ul class="toc-item"><li><span><a href="#assess-metrics-for-model" data-toc-modified-id="assess-metrics-for-model-8.3.1"><span class="toc-item-num">8.3.1&nbsp;&nbsp;</span>assess metrics for model</a></span></li></ul></li></ul></li><li><span><a href="#realizing-my-mistake,-I-corrected-and-applied-tfidf-vector-fit-and-transformation-on-training-set-then-transformed-test-set-accordingly-to-prevent-leakage" data-toc-modified-id="realizing-my-mistake,-I-corrected-and-applied-tfidf-vector-fit-and-transformation-on-training-set-then-transformed-test-set-accordingly-to-prevent-leakage-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>realizing my mistake, I corrected and applied tfidf vector fit and transformation on training set then transformed test set accordingly to prevent leakage</a></span><ul class="toc-item"><li><span><a href="#prepare-data-for-model" data-toc-modified-id="prepare-data-for-model-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>prepare data for model</a></span></li><li><span><a href="#apply-smote-to-target-data-due-to-unbalanced-data" data-toc-modified-id="apply-smote-to-target-data-due-to-unbalanced-data-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>apply smote to target data due to unbalanced data</a></span></li><li><span><a href="#nn-model-#1" data-toc-modified-id="nn-model-#1-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>nn model #1</a></span></li><li><span><a href="#nn_model-#2" data-toc-modified-id="nn_model-#2-9.4"><span class="toc-item-num">9.4&nbsp;&nbsp;</span>nn_model #2</a></span></li></ul></li><li><span><a href="#define-3-fold-cross-validation-test-harness" data-toc-modified-id="define-3-fold-cross-validation-test-harness-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>define 3 fold cross validation test harness</a></span></li><li><span><a href="#which-model-used" data-toc-modified-id="which-model-used-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>which model used</a></span></li><li><span><a href="#Compile-model" data-toc-modified-id="Compile-model-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Compile model</a></span><ul class="toc-item"><li><span><a href="#nn-model-3" data-toc-modified-id="nn-model-3-12.1"><span class="toc-item-num">12.1&nbsp;&nbsp;</span>nn model 3</a></span></li></ul></li><li><span><a href="#nn-model-no-SMOTE,-use-weights" data-toc-modified-id="nn-model-no-SMOTE,-use-weights-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>nn model no SMOTE, use weights</a></span></li><li><span><a href="#create-sequential-model" data-toc-modified-id="create-sequential-model-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>create sequential model</a></span></li><li><span><a href="#sigmoid-activation-layer" data-toc-modified-id="sigmoid-activation-layer-15"><span class="toc-item-num">15&nbsp;&nbsp;</span>sigmoid activation layer</a></span></li><li><span><a href="#output-layer-with-sigmoid-activation-for-binary-target" data-toc-modified-id="output-layer-with-sigmoid-activation-for-binary-target-16"><span class="toc-item-num">16&nbsp;&nbsp;</span>output layer with sigmoid activation for binary target</a></span><ul class="toc-item"><li><span><a href="#model-and-assess-using-statistical-methods" data-toc-modified-id="model-and-assess-using-statistical-methods-16.1"><span class="toc-item-num">16.1&nbsp;&nbsp;</span>model and assess using statistical methods</a></span></li></ul></li><li><span><a href="#word2vec" data-toc-modified-id="word2vec-17"><span class="toc-item-num">17&nbsp;&nbsp;</span>word2vec</a></span></li><li><span><a href="#hashtag-frequency-analysis" data-toc-modified-id="hashtag-frequency-analysis-18"><span class="toc-item-num">18&nbsp;&nbsp;</span>hashtag frequency analysis</a></span><ul class="toc-item"><li><span><a href="#create-dataframe-with-tweets-containing-&quot;rt&quot;-for-retweet-assessment-later" data-toc-modified-id="create-dataframe-with-tweets-containing-&quot;rt&quot;-for-retweet-assessment-later-18.1"><span class="toc-item-num">18.1&nbsp;&nbsp;</span>create dataframe with tweets containing "rt" for retweet assessment later</a></span></li></ul></li><li><span><a href="#Final-Model" data-toc-modified-id="Final-Model-19"><span class="toc-item-num">19&nbsp;&nbsp;</span>Final Model</a></span></li></ul></div>

# %%
#import modules for Obtain/Scrub/Explore
import re
import pandas as pd 
import numpy as np 
import nltk
import string
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings 
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)
# %matplotlib inline

# %%
#import modules for tokenizing and stemming 
from nltk.collocations import *
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
import nltk
from nltk import pos_tag
from collections import defaultdict
from nltk.stem import WordNetLemmatizer 
from collections import Counter
from nltk.tokenize.treebank import TreebankWordTokenizer, TreebankWordDetokenizer
from nltk.probability import FreqDist

# %% [markdown]
# ## functions

# %%
# function using contraction dictionary to replace/expand contractions
cList = {
  "ain't": "aint",
  "aren't": "are not",
  "can't": "can not",
  "can't've": "can not have",
  "'cause": "because",
  "bc": "because",
  "b/c": "because",
  "could've": "could have",
  "couldn't": "could not",
  "couldn't've": "could not have",
  "didn't": "did not",
  "doesn't": "does not",
  "don't": "do not",
  "hadn't": "had not",
  "hadn't've": "had not have",
  "hasn't": "has not",
  "haven't": "have not",
  "he'd": "he would",
  "he'd've": "he would have",
  "he'll": "he will",
  "he'll've": "he will have",
  "he's": "he is",
  "how'd": "how did",
  "how'd'y": "how do you",
  "how'll": "how will",
  "how's": "how is",
  "I'd": "I would",
  "I'd've": "I would have",
  "I'll": "I will",
  "I'll've": "I will have",
  "I'm": "I am",
  "I've": "I have",
  "isn't": "is not",
  "it'd": "it had",
  "it'd've": "it would have",
  "it'll": "it will",
  "it'll've": "it will have",
  "it's": "it is",
  "let's": "let us",
  "ma'am": "madam",
  "mayn't": "may not",
  "might've": "might have",
  "mightn't": "might not",
  "mightn't've": "might not have",
  "must've": "must have",
  "mustn't": "must not",
  "mustn't've": "must not have",
  "needn't": "need not",
  "needn't've": "need not have",
  "o'clock": "of the clock",
  "oughtn't": "ought not",
  "oughtn't've": "ought not have",
  "shan't": "shall not",
  "sha'n't": "shall not",
  "shan't've": "shall not have",
  "she'd": "she would",
  "she'd've": "she would have",
  "she'll": "she will",
  "she'll've": "she will have",
  "she's": "she is",
  "should've": "should have",
  "shouldn't": "should not",
  "shouldn't've": "should not have",
  "so've": "so have",
  "so's": "so is",
  "that'd": "that would",
  "that'd've": "that would have",
  "that's": "that is",
  "there'd": "there had",
  "there'd've": "there would have",
  "there's": "there is",
  "they'd": "they would",
  "they'd've": "they would have",
  "they'll": "they will",
  "they'll've": "they will have",
  "they're": "they are",
  "they've": "they have",
  "to've": "to have",
  "wasn't": "was not",
  "we'd": "we had",
  "we'd've": "we would have",
  "we'll": "we will",
  "we'll've": "we will have",
  "we're": "we are",
  "we've": "we have",
  "weren't": "were not",
  "what'll": "what will",
  "what'll've": "what will have",
  "what're": "what are",
  "what's": "what is",
  "what've": "what have",
  "when's": "when is",
  "when've": "when have",
  "where'd": "where did",
  "where's": "where is",
  "where've": "where have",
  "who'll": "who will",
  "who'll've": "who will have",
  "who's": "who is",
  "who've": "who have",
  "why's": "why is",
  "why've": "why have",
  "will've": "will have",
  "won't": "will not",
  "won't've": "will not have",
  "would've": "would have",
  "wouldn't": "would not",
  "wouldn't've": "would not have",
  "y'all": "you all",
  "y'alls": "you alls",
  "y'all'd": "you all would",
  "y'all'd've": "you all would have",
  "y'all're": "you all are",
  "y'all've": "you all have",
  "you'd": "you had",
  "you'd've": "you would have",
  "you'll": "you you will",
  "you'll've": "you you will have",
  "you're": "you are",
  "you've": "you have"
}

c_re = re.compile('(%s)' % '|'.join(cList.keys()))

def expandContractions(text, c_re=c_re):
    def replace(match):
        return cList[match.group(0)]
    return c_re.sub(replace, text)

# %%
# function to clean up characters and unwanted items from tweet text
def scrub_tweet(df):
    for x in df:
        # expand contractions
        df = df.apply(expandContractions)
        # remove hash from tweet column, keeping word following hashtag
        df = df.str.replace(r"#", " ")
        # remove hyperlinks and {link}
        df = df.str.replace(r"(?:\@|http?\://|https?\://|www)\S+", " ")
        df = df.str.replace(r'{link}', " ")
        # remove random characters and punctuation
        df = df.str.replace(r'[^a-zA-Z]', " ")
        #remove digits
        df = df.str.replace(r'\d', " ")
        # deal with apostrophes
        df = df.str.replace(r'(\')', "")
        # remove individual/single chars
        df = df.str.replace(r'\b[a-z]\b', "")
        # remove double spaces
        df = df.str.replace(r'  ', " ")
   
  
        return df

# %%
stopwords_list = (stopwords.words('english')) 
add_stopwords = ('apple', 'ipad', 'iphone', 'android', 'ipadiphone', 'google', 'app', 
                 'sxsw', 'sxswi', 'itunes', 'g', 'c', 'b', 'w', 'austin')
stopwords_list.extend(add_stopwords)

# %%
# function to remove stopwords from tweet pre-tokenize
def remove_stop_text(df):
    temp= df.apply(lambda x: ' '.join([word for word in x.split() 
                                                if word not in (stopwords_list)]))
    return temp

# %%
# function to remove stopwords from tweet post-tokenize
def stop_rem(words):
    tokens = [
    w for w in words 
        if w not in stopwords_list
    ]

# %%
# apply defined tokenizer to text
def toke_text(words):
    tokens = tokenizer.tokenize(words)
    return tokens

# %%
# apply defined lemmatizer to tokens
def lem_text(tokens):
    new_df = [lemmatizer.lemmatize(x) for x in tokens]
    return new_df

# %%
# apply defined stemmer to tokens
def stem_text(tokens):
    new_df = [stemmer.stem(x) for x in tokens]
    return new_df

# %%
# word frequency top 50
def top_50(df):
    temp = df.to_list()
    temp2 = [i for j in temp for i in j]
    temp_freqdist = FreqDist(temp2)
    print('50 MOST common words:', (temp_freqdist.most_common(50)))
    print('Total:', (len(temp_freqdist)))

# %% [markdown]
# # Obtain data

# %%
data = pd.read_csv('data/data.csv', sep=',')

# %%
data.tweet_text.iloc[4]
# Out:
# "@sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) &amp; Matt Mullenweg (Wordpress)"

# %%
data.head()
# Out:
#                                           tweet_text  \
# 0  .@wesley83 I have a 3G iPhone. After 3 hrs twe...
# 1  @jessedee Know about @fludapp ? Awesome iPad/i...
# 2  @swonderlin Can not wait for #iPad 2 also. The...
# 3  @sxsw I hope this year's festival isn't as cra...
# 4  @sxtxstate great stuff on Fri #SXSW: Marissa M...
#
#   emotion_in_tweet_is_directed_at  \
# 0                          iPhone
# 1              iPad or iPhone App
# 2                            iPad
# 3              iPad or iPhone App
# 4                          Google
#
#   is_there_an_emotion_directed_at_a_brand_or_product
# 0                                   Negative emotion
# 1                                   Positive emotion
# 2                                   Positive emotion
# 3                                   Negative emotion
# 4                                   Positive emotion

# %%
data.columns
# Out:
# Index(['tweet_text', 'emotion_in_tweet_is_directed_at',
#        'is_there_an_emotion_directed_at_a_brand_or_product'],
#       dtype='object')

# %%
data.dtypes
# Out:
# tweet_text                                            object
# emotion_in_tweet_is_directed_at                       object
# is_there_an_emotion_directed_at_a_brand_or_product    object
# dtype: object

# %%
data.shape
# Out:
# (8721, 3)

# %%
data = data.rename(columns={'tweet_text': 'tweet', 'emotion_in_tweet_is_directed_at': "product", 'is_there_an_emotion_directed_at_a_brand_or_product': 'sentiment'})

# %%
data.drop_duplicates(subset='tweet', keep='first', inplace=True)

# %% [markdown]
# # Scrub data

# %% [markdown]
# ##  missing data

# %% [markdown]
# ### missing tweet data

# %%
data['tweet'].isna().sum()
# Out:
# 1

# %%
data.isna().sum()
# Out:
# tweet           1
# product      5536
# sentiment       0
# dtype: int64

# %%
data.dropna(subset=['tweet'], axis=0, inplace=True)

# %%
data.shape
# Out:
# (8693, 3)

# %%
data['tweet'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### missing product data

# %%
# make tweet text lowercase for continuity
data['product'] = data['product'].str.lower()

# %%
data['product'].isna().sum()
# Out:
# 5535

# %%
# make tweet text lowercase for continuity
data['tweet'] = data['tweet'].str.lower()

# %%
# fill product column using keywords from tweet text
data.loc[(data['product'].isnull()) & (data['tweet'].str.contains('ipad')), 'product'] = 'ipad'
data.loc[(data['product'].isnull()) & (data['tweet'].str.contains('iphone')), 'product'] = 'iphone'                                     
data.loc[(data['product'].isnull()) & (data['tweet'].str.contains('apple')), 'product'] = 'apple'
data.loc[(data['product'].isnull()) & (data['tweet'].str.contains('android')), 'product'] = 'android'
data.loc[(data['product'].isnull()) & (data['tweet'].str.contains('google')), 'product'] = 'google'
data.loc[(data['product'].isnull()) & (data['tweet'].str.contains('itunes')), 'product'] = 'apple app'

# %%
data['product'].unique()
# Out:
# array(['iphone', 'ipad or iphone app', 'ipad', 'google', 'android',
#        'apple', 'android app', 'other google product or service', nan,
#        'apple app', 'other apple product or service'], dtype=object)

# %%
data.dropna(subset=['product'], axis=0, inplace=True)

# %%
data.shape
# Out:
# (8014, 3)

# %%
data['product'].unique()
# Out:
# array(['iphone', 'ipad or iphone app', 'ipad', 'google', 'android',
#        'apple', 'android app', 'other google product or service',
#        'apple app', 'other apple product or service'], dtype=object)

# %%
# update values in product column
data['product'] = data['product'].replace(['other apple product or service'], 'apple other')
data['product'] = data['product'].replace(['ipad or iphone app'], 'apple app')
data['product'] = data['product'].replace(['ipad'], 'apple ipad')
data['product'] = data['product'].replace(['iphone'], 'apple iphone')
data['product'] = data['product'].replace(['android app'], 'android app')
data['product'] = data['product'].replace(['android'], 'android')
data['product'] = data['product'].replace(['google'], 'google')
data['product'] = data['product'].replace(['other google product or service'], 'google other')
data['product'] = data['product'].replace(['apple'], 'apple')

# %% [markdown]
# ## remove twitter handles from tweet text

# %%
data['tweet'] = data.apply(lambda row: 
    nltk.tokenize.casual.remove_handles(row['tweet']), axis=1)

# %%
from bs4 import BeautifulSoup

data['tweet'] = data.apply(lambda row: BeautifulSoup(row['tweet']).get_text().replace('\n',' '),axis=1)

# %%
data.head()
# Out:
#                                                tweet       product  \
# 0  .  i have a 3g iphone. after 3 hrs tweeting at...  apple iphone
# 1  know about   ? awesome ipad/iphone app that yo...     apple app
# 2  can not wait for #ipad 2 also. they should sal...    apple ipad
# 3  i hope this year's festival isn't as crashy as...     apple app
# 4  great stuff on fri #sxsw: marissa mayer (googl...        google
#
#           sentiment
# 0  Negative emotion
# 1  Positive emotion
# 2  Positive emotion
# 3  Negative emotion
# 4  Positive emotion

# %% [markdown]
# ## create hashtag column

# %%
# create column with hashtags as list
data['hashtags'] = data['tweet'].apply(lambda twt : re.findall(r"#(\w+)", twt))

# %% [markdown]
# ## clean tweet text

# %%
data.head()
# Out:
#                                                tweet       product  \
# 0  .  i have a 3g iphone. after 3 hrs tweeting at...  apple iphone
# 1  know about   ? awesome ipad/iphone app that yo...     apple app
# 2  can not wait for #ipad 2 also. they should sal...    apple ipad
# 3  i hope this year's festival isn't as crashy as...     apple app
# 4  great stuff on fri #sxsw: marissa mayer (googl...        google
#
#           sentiment             hashtags
# 0  Negative emotion  [rise_austin, sxsw]
# 1  Positive emotion               [sxsw]
# 2  Positive emotion         [ipad, sxsw]
# 3  Negative emotion               [sxsw]
# 4  Positive emotion               [sxsw]

# %%
# scrub/ clean tweet text
data['clean_tweet'] = scrub_tweet(data['tweet'])

# %% [markdown]
# # sentiment column clean up

# %%
# update values in sentiment column
data['sentiment'] = data['sentiment'].replace(['Negative emotion'], 'negative')
data['sentiment'] = data['sentiment'].replace(['Positive emotion'], 'positive')
data['sentiment'] = data['sentiment'].replace(['No emotion toward brand or product'], 'neutral')
data['sentiment'] = data['sentiment'].replace(['I can\'t tell'], 'unknown')

# %%
data.sentiment.describe()
# Out:
# count        8014
# unique          4
# top       neutral
# freq         4476
# Name: sentiment, dtype: object

# %%
# assess 'unknown' sentiment values
data.loc[data['sentiment']=='unknown']
# Out:
#                                                   tweet       product  \
# 100   ���  "apple has opened a pop-up store in austi...    apple ipad
# 228   just what america needs. rt   google to launch...        google
# 330   the queue at the apple store in austin is four...         apple
# 357   hope it's better than wave rt   buzz is: googl...        google
# 402   syd #sxsw crew your iphone extra juice pods ha...  apple iphone
# ...                                                 ...           ...
# 8650  it's funny watching a room full of people hold...    apple ipad
# 8662  yeah, we have   , google has nothing on us :) ...        google
# 8667  yes, the google presentation was not exactly w...        google
# 8687  "do you know what apple is really good at? mak...    apple ipad
# 8695  how much you want to bet apple is disproportio...         apple
#
#      sentiment                     hashtags  \
# 100    unknown                  [sxsw, wow]
# 228    unknown                       [sxsw]
# 330    unknown                       [sxsw]
# 357    unknown                       [sxsw]
# 402    unknown                       [sxsw]
# ...        ...                          ...
# 8650   unknown                       [sxsw]
# 8662   unknown                       [sxsw]
# 8667   unknown                       [sxsw]
# 8687   unknown  [sxsw, doyoureallyneedthat]
# 8695   unknown                       [sxsw]
#
#                                             clean_tweet
# 100      apple has opened pop up store in austin so ...
# 228   just what america needs rt  google to launch m...
# 330   the queue at the apple store in austin is four...
# 357   hope it is better than wave rt  buzz is google...
# 402   syd sxsw crew your iphone extra juice pods hav...
# ...                                                 ...
# 8650  it is funny watching room full of people hold ...
# 8662     yeah we have   google has nothing on us   sxsw
# 8667  yes the google presentation was not exactly wh...
# 8687   do you know what apple is really good at maki...
# 8695  how much you want to bet apple is disproportio...
#
# [146 rows x 5 columns]

# %% [markdown]
# # Explore

# %%
fig, ax = plt.subplots(figsize=(18,8))
x = data['product']
hue = data['sentiment']
ax = sns.countplot(x, hue=hue, data=data)
plt.title('Product by Sentiment', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Product by Sentiment')

# %%
data.columns
# Out:
# Index(['tweet', 'product', 'sentiment', 'hashtags', 'clean_tweet'], dtype='object')

# %%
brand_df = data.copy()
brand_df.drop(['tweet', 'hashtags', 'clean_tweet'], axis=1, inplace=True)

# update values in product column
brand_df.loc[(brand_df['product'].str.contains('apple')), 'product'] = 'apple'
brand_df.loc[(brand_df['product'].str.contains('android')), 'product'] = 'android/google'
brand_df.loc[(brand_df['product'].str.contains('google')), 'product'] = 'android/google'
brand_df.head()
# Out:
#           product sentiment
# 0           apple  negative
# 1           apple  positive
# 2           apple  positive
# 3           apple  negative
# 4  android/google  positive

# %%
fig, ax = plt.subplots(figsize=(18,8))
x = brand_df['product']
hue = brand_df['sentiment']
ax = sns.countplot(x, hue=hue, data=data)
plt.title('Brand by Sentiment', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Brand by Sentiment')

# %%
data['product'].value_counts(normalize=True)
# Out:
# apple ipad      0.301348
# google          0.252433
# apple           0.162965
# apple iphone    0.135887
# apple app       0.063015
# android         0.035313
# google other    0.035188
# android app     0.009608
# apple other     0.004243
# Name: product, dtype: float64

# %%
plt.figure(figsize=(11,11))
colors = ['lightblue', 'silver', 'orange', 'pink', 'red', 'purple', 'blue', 'yellow', 'brown']
expl = (0, 0.1)
data['product'].value_counts().plot(kind='bar', legend=False, colors=colors)
plt.title('Product Count', fontsize=20)
# Out:
# /Users/badmin/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:203: UserWarning: 'colors' is being deprecated. Please use 'color'instead of 'colors'
#   "'colors' is being deprecated. Please use 'color'"
# Text(0.5, 1.0, 'Product Count')

# %%
data['sentiment'].value_counts()
# Out:
# neutral     4476
# positive    2849
# negative     543
# unknown      146
# Name: sentiment, dtype: int64

# %%
plt.figure(figsize=(11,11))
colors = ['lightblue', 'silver', 'orange', 'pink']
expl = (0, 0.1)
data.sentiment.value_counts().plot(kind='pie', legend=True, startangle=45, shadow=True, 
                             colors=colors, autopct='%1.1f%%')
plt.title('Sentiment Count', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Sentiment Count')

# %%
import itertools
# pre cleaned corpus
corpus1 = list(itertools.chain(*[nltk.word_tokenize(tok) for tok in data.tweet]))
print(len(corpus1))
# Out:
# 179247

# %% [markdown]
# # More Scrubbing

# %% [markdown]
# ## stopwords assessment and removal

# %%
# remove stopwords from tweet text
data['words'] = remove_stop_text(data.clean_tweet)

# %% [markdown]
# ## tokenize, lemmatize, stemming

# %%
#tokenizer = RegexpTokenizer("[\w']+")
stemmer = nltk.stem.SnowballStemmer('english')
tokenizer = TreebankWordTokenizer()
detokenizer = TreebankWordDetokenizer()
lemmatizer = lemmatizer = WordNetLemmatizer()

# %%
# tokenize/stem tweet text
data['tokenized'] = data.words.map(toke_text)
#data['tokens'] = data.tokenized.map(stem_text)
data['tokens'] = [stem_text(tok) for tok in data.tokenized]
data['tokenl'] = [lem_text(tok) for tok in data.tokenized]

data['wordl'] = [detokenizer.detokenize(tok) for tok in data.tokenl]
data['wordss'] = [detokenizer.detokenize(tok) for tok in data.tokens]
data['pos_s'] = data.tokens.map(pos_tag)
data['pos_l'] = data.tokenl.map(pos_tag)

# %%
# post cleaned corpus for stemmed tokens
corpus_s = list(itertools.chain(*[nltk.word_tokenize(tok) for tok in data.words]))
print(len(corpus_s))
# Out:
# 65347

# %%
# post cleaned corpus for lemmatized tokens
corpus_l = list(itertools.chain(*[nltk.word_tokenize(tok) for tok in data.wordl]))
print(len(corpus_l))
# Out:
# 65313

# %%
data['num_sentiment'] = data['sentiment'].replace(['Negative emotion'], 0)
data['num_sentiment'] = data['sentiment'].replace(['Positive emotion'], 1)
data['num_sentiment'] = data['sentiment'].replace(['No emotion toward brand or product'], 2)
data['num_sentiment'] = data['sentiment'].replace(['I can\'t tell'], 3)

# %% [markdown]
# # further exploration of only positive and negative sentiment

# %% [markdown]
# ## of only positive and negative sentiment

# %%
# create dataframe with only positive and negative sentiment
df = data.copy()
df = df[df['sentiment'].isin(['positive', 'negative']) ]
col = ['wordss', 'tokens', 'wordl', 'tokenl', 'pos_s', 'pos_l', 'sentiment', 'num_sentiment']
df = df[col]

# %%
# Creating the dicti
word_dict = {} 

for row in df.wordss: 
    words = tokenizer.tokenize(row) 
    for word in words: 
        if word not in word_dict.keys(): 
            word_dict[word] = 1
        else: 
            word_dict[word] += 1
print(len(word_dict))
max(word_dict, key=word_dict.get)
# Out:
# 4296
# 'rt'

# %%
# Creating the dicti
word_dict_l = {} 

for row in df.wordl: 
    words = tokenizer.tokenize(row) 
    for word in words: 
        if word not in word_dict_l.keys(): 
            word_dict_l[word] = 1
        else: 
            word_dict_l[word] += 1
print(len(word_dict_l))
max(word_dict_l, key=word_dict_l.get)
word_dict_l
# Out:
# 5058
# {'hr': 4,
#  'tweeting': 13,
#  'rise': 7,
#  'dead': 4,
#  'need': 97,
#  'upgrade': 8,
#  'plugin': 4,
#  'station': 4,
#  'know': 61,
#  'awesome': 93,
#  'likely': 3,
#  'appreciate': 4,
#  'design': 66,
#  'also': 45,
#  'giving': 30,
#  'free': 120,
#  't': 2,
#  'wait': 50,
#  'sale': 19,
#  'hope': 23,
#  'year': 84,
#  'festival': 15,
#  'crashy': 2,
#  'great': 138,
#  'stuff': 20,
#  'fri': 5,
#  'marissa': 64,
#  'mayer': 76,
#  'tim': 11,
#  'reilly': 4,
#  'tech': 57,
#  'book': 23,
#  'conference': 48,
#  'matt': 4,
#  'mullenweg': 2,
#  'wordpress': 3,
#  'starting': 6,
#  'ctia': 1,
#  'around': 70,
#  'corner': 5,
#  'googleio': 1,
#  'hop': 2,
#  'skip': 2,
#  'jump': 5,
#  'good': 103,
#  'time': 154,
#  'fan': 17,
#  'beautifully': 2,
#  'smart': 48,
#  'simple': 6,
#  'idea': 25,
#  'rt': 1063,
#  'wrote': 6,
#  'hollergram': 23,
#  'counting': 1,
#  'day': 147,
#  'plus': 9,
#  'strong': 6,
#  'canadian': 4,
#  'dollar': 6,
#  'mean': 17,
#  'stock': 9,
#  'gear': 1,
#  'excited': 31,
#  'meet': 22,
#  'show': 38,
#  'sprint': 2,
#  'galaxy': 3,
#  'still': 49,
#  'running': 10,
#  'fail': 23,
#  'find': 24,
#  'start': 19,
#  'impromptu': 2,
#  'party': 156,
#  'til': 8,
#  'come': 110,
#  'foursquare': 19,
#  'ups': 3,
#  'game': 51,
#  'prefer': 5,
#  'far': 32,
#  'best': 69,
#  'looking': 35,
#  'date': 2,
#  'got': 97,
#  'ta': 11,
#  'love': 97,
#  'calendar': 10,
#  'featuring': 4,
#  'top': 20,
#  'case': 59,
#  'check': 87,
#  'via': 134,
#  'haha': 11,
#  'awesomely': 6,
#  'rad': 11,
#  'noticed': 1,
#  'dst': 1,
#  'coming': 47,
#  'weekend': 23,
#  'many': 35,
#  'user': 78,
#  'hour': 42,
#  'late': 17,
#  'sunday': 4,
#  'morning': 16,
#  'added': 5,
#  'flight': 13,
#  'matching': 3,
#  'people': 111,
#  'plane': 9,
#  'airport': 10,
#  'downloaded': 7,
#  'nicely': 3,
#  'done': 12,
#  'must': 33,
#  'lovely': 5,
#  'review': 10,
#  'forbes': 2,
#  'holler': 16,
#  'gram': 16,
#  'buy': 45,
#  'sure': 23,
#  'store': 584,
#  'oh': 31,
#  'god': 19,
#  'pure': 5,
#  'unadulterated': 1,
#  'easier': 6,
#  'browse': 1,
#  'event': 30,
#  'website': 12,
#  'okay': 4,
#  'really': 64,
#  'yay': 9,
#  'new': 394,
#  'kthxbai': 2,
#  'photo': 45,
#  'installed': 5,
#  'nice': 55,
#  'enjoying': 11,
#  'change': 10,
#  'gowalla': 19,
#  'forward': 23,
#  'seeing': 16,
#  'else': 13,
#  'sleeve': 2,
#  'smcdallas': 3,
#  'pre': 7,
#  'wed': 4,
#  'hoping': 6,
#  'win': 122,
#  'resulting': 3,
#  'shameless': 3,
#  'promotion': 4,
#  'chevysmc': 3,
#  'someone': 31,
#  'started': 11,
#  'group': 20,
#  'sq': 7,
#  'look': 78,
#  'like': 152,
#  'going': 79,
#  'rock': 25,
#  'update': 32,
#  'push': 6,
#  'tonight': 31,
#  'keepaustinweird': 2,
#  'right': 48,
#  'sweeeeet': 2,
#  'job': 22,
#  'team': 49,
#  'may': 38,
#  'leave': 8,
#  'vuvuzela': 3,
#  'home': 21,
#  'ha': 9,
#  'first': 75,
#  'line': 162,
#  'pop': 219,
#  'planner': 2,
#  'eventprofs': 1,
#  'pcma': 1,
#  'engage': 2,
#  'false': 4,
#  'alarm': 7,
#  'circle': 158,
#  'probably': 14,
#  'ever': 61,
#  'social': 152,
#  'weather': 3,
#  'greet': 1,
#  'sweater': 1,
#  'night': 25,
#  'putting': 9,
#  'flash': 11,
#  'downtown': 86,
#  'sell': 30,
#  'hand': 37,
#  'held': 7,
#  'hobo': 7,
#  'drafthouse': 3,
#  'launch': 188,
#  'shotgun': 4,
#  'hooray': 3,
#  'opening': 89,
#  'wooooo': 3,
#  'open': 83,
#  'midnight': 4,
#  'talking': 10,
#  'effort': 4,
#  'allow': 3,
#  'system': 4,
#  'bettercloud': 1,
#  'st': 19,
#  'stop': 22,
#  'chaos': 1,
#  'hunt': 4,
#  'java': 2,
#  'get': 199,
#  'spy': 2,
#  'chance': 7,
#  'insane': 4,
#  'attending': 10,
#  'headache': 19,
#  'boooo': 1,
#  'flipboard': 27,
#  'developing': 5,
#  'version': 22,
#  'say': 54,
#  'power': 14,
#  'band': 18,
#  'food': 21,
#  'art': 21,
#  'ice': 5,
#  'cream': 5,
#  'nifty': 2,
#  'interactive': 28,
#  'map': 121,
#  'holla': 2,
#  'butt': 5,
#  'phone': 63,
#  'post': 11,
#  'make': 64,
#  'easy': 5,
#  'connect': 13,
#  'network': 108,
#  'behaving': 2,
#  'today': 132,
#  'crash': 6,
#  'yesterday': 7,
#  'ridiculous': 9,
#  'hey': 38,
#  'peek': 3,
#  'space': 14,
#  'slated': 3,
#  'tomorrow': 32,
#  'one': 168,
#  'thing': 65,
#  'earth': 9,
#  'face': 4,
#  'company': 32,
#  'sxwsi': 1,
#  'thanks': 75,
#  'mention': 7,
#  'speech': 7,
#  'apps': 108,
#  'showcased': 5,
#  'conf': 6,
#  'sxswh': 4,
#  'sxsh': 3,
#  'provide': 1,
#  'charger': 22,
#  'changed': 6,
#  'mind': 9,
#  'next': 64,
#  'xmas': 1,
#  'shiny': 10,
#  'christmas': 6,
#  'nerd': 20,
#  'yai': 1,
#  'ubersocial': 24,
#  'includes': 25,
#  'uberguide': 24,
#  'sponsored': 21,
#  'cont': 14,
#  'fast': 33,
#  'fun': 49,
#  'future': 32,
#  'presenting': 4,
#  'search': 45,
#  'local': 4,
#  'mobile': 106,
#  'headline': 1,
#  'gadget': 11,
#  'hmm': 8,
#  'could': 46,
#  'seen': 23,
#  'dataviz': 1,
#  'translates': 1,
#  'satanic': 1,
#  'sayin': 1,
#  'launched': 18,
#  'checkins': 9,
#  'month': 13,
#  'ago': 5,
#  'in': 2,
#  'ok': 7,
#  'out': 1,
#  'bizzy': 9,
#  'tweet': 48,
#  'think': 77,
#  'speak': 18,
#  'mark': 12,
#  'belinsky': 12,
#  'panel': 51,
#  'kawasaki': 10,
#  'lewis': 2,
#  'level': 5,
#  'reasoning': 1,
#  'continued': 7,
#  'existence': 9,
#  'evidence': 2,
#  'bawling': 1,
#  'pagemaker': 3,
#  'saved': 11,
#  'jwtatl': 1,
#  'enchantment': 11,
#  'spark': 2,
#  'teamandroid': 2,
#  'award': 15,
#  'read': 17,
#  'thought': 18,
#  'japan': 31,
#  'apac': 1,
#  'region': 1,
#  'dealing': 2,
#  'earthquake': 3,
#  'tsunami': 2,
#  'trauma': 1,
#  'school': 27,
#  'marketing': 43,
#  'expert': 25,
#  'temporary': 89,
#  'def': 6,
#  'tent': 2,
#  'powerhouse': 2,
#  'gym': 6,
#  'th': 36,
#  'congress': 27,
#  'along': 3,
#  'happy': 26,
#  'hipster': 15,
#  'support': 12,
#  'christian': 1,
#  'devs': 4,
#  'want': 69,
#  'talk': 44,
#  'maybe': 13,
#  'wk': 1,
#  'together': 10,
#  'cool': 121,
#  'taken': 4,
#  'storm': 1,
#  'part': 12,
#  'haz': 2,
#  'ifrom': 1,
#  'gr': 3,
#  'stack': 1,
#  'waiting': 19,
#  'bought': 16,
#  'mine': 5,
#  'hassle': 1,
#  'handled': 1,
#  'perfectly': 2,
#  'smallbiz': 2,
#  'play': 14,
#  'place': 33,
#  'seo': 6,
#  'take': 54,
#  'major': 73,
#  'south': 10,
#  'korean': 1,
#  'director': 4,
#  'movie': 6,
#  'entirely': 2,
#  'beautiful': 7,
#  'pic': 23,
#  'sneaky': 2,
#  'usual': 2,
#  'beta': 5,
#  'testing': 6,
#  'moonbot': 3,
#  'studio': 3,
#  'louisiana': 3,
#  'ton': 11,
#  'sold': 23,
#  'everything': 14,
#  'except': 10,
#  'gig': 8,
#  'wifi': 20,
#  'white': 27,
#  'manage': 2,
#  'known': 2,
#  'jean': 4,
#  'configuration': 1,
#  'offered': 2,
#  'promo': 5,
#  'ninjafinder': 2,
#  'suck': 15,
#  'lonelyplanet': 1,
#  'guide': 23,
#  'limited': 5,
#  'lp': 11,
#  'travel': 9,
#  'short': 4,
#  'left': 16,
#  'tradeshow': 7,
#  'demo': 30,
#  'theatre': 3,
#  'see': 88,
#  'presenter': 2,
#  'using': 53,
#  'anyone': 24,
#  'quick': 4,
#  'hundred': 6,
#  'ad': 15,
#  'hoc': 2,
#  'cost': 4,
#  'monday': 3,
#  'barry': 10,
#  'diller': 16,
#  'york': 3,
#  'lunch': 4,
#  'hotel': 8,
#  'six': 6,
#  'dirty': 1,
#  'martini': 1,
#  'seriously': 7,
#  'constant': 3,
#  'causing': 2,
#  'lost': 11,
#  'schedule': 15,
#  'sync': 6,
#  'wp': 2,
#  'ready': 31,
#  'ur': 12,
#  'blogging': 4,
#  'conflagration': 1,
#  'doofusness': 1,
#  'attention': 7,
#  'er': 6,
#  'rumored': 4,
#  'went': 9,
#  'lousy': 1,
#  'winning': 29,
#  'picture': 13,
#  'spent': 8,
#  'already': 37,
#  'used': 23,
#  'couple': 5,
#  'city': 10,
#  'block': 23,
#  'behind': 13,
#  'email': 3,
#  'give': 26,
#  'composed': 2,
#  'reply': 1,
#  'protip': 2,
#  'pm': 20,
#  'popup': 74,
#  'selling': 13,
#  'wild': 3,
#  'terrible': 3,
#  'video': 60,
#  'snapping': 1,
#  'away': 39,
#  'keynote': 12,
#  'slide': 4,
#  'southwest': 6,
#  'sweet': 19,
#  'ballroom': 9,
#  'million': 19,
#  'mile': 6,
#  'per': 9,
#  'driving': 6,
#  'navigation': 16,
#  'share': 24,
#  'track': 10,
#  'audience': 11,
#  'stage': 3,
#  'use': 64,
#  'frostwire': 3,
#  'wi': 3,
#  'fi': 3,
#  'available': 26,
#  'car': 5,
#  'zimride': 1,
#  'etc': 8,
#  'ride': 2,
#  'shareable': 1,
#  'picked': 11,
#  'mophie': 8,
#  'battery': 26,
#  'prep': 4,
#  'lugging': 2,
#  'laptop': 31,
#  'huge': 17,
#  'last': 45,
#  'rumor': 39,
#  'monger': 1,
#  'preview': 11,
#  'socbiz': 1,
#  'fb': 24,
#  'yes': 45,
#  'please': 15,
#  'build': 4,
#  'le': 6,
#  'biggest': 7,
#  'history': 5,
#  'groupme': 7,
#  'sound': 17,
#  'incredible': 1,
#  'yet': 24,
#  'botch': 1,
#  'timechange': 1,
#  'freak': 2,
#  'missed': 8,
#  'bloody': 2,
#  'mary': 1,
#  'shout': 5,
#  'lady': 3,
#  'holding': 8,
#  'sipping': 1,
#  'beer': 5,
#  'cc': 19,
#  'meant': 2,
#  'wish': 20,
#  'dyac': 1,
#  'stupid': 8,
#  'sign': 10,
#  'point': 12,
#  'minute': 11,
#  'brilliant': 27,
#  'enlightening': 1,
#  'mechanic': 2,
#  'presentation': 22,
#  'genius': 26,
#  'dictaphone': 1,
#  'vid': 3,
#  'camera': 19,
#  'wow': 46,
#  'real': 17,
#  'cerebellum': 1,
#  'charged': 5,
#  'personal': 2,
#  'found': 10,
#  'kyping': 2,
#  'geolocation': 4,
#  'releasing': 4,
#  'background': 2,
#  'patch': 2,
#  'batterykiller': 3,
#  'live': 36,
#  'rsvp': 4,
#  'sundayswagger': 1,
#  'eventbrite': 1,
#  'com': 24,
#  'scoremore': 1,
#  'course': 10,
#  'built': 13,
#  'temp': 38,
#  'texas': 16,
#  'understand': 3,
#  'concept': 7,
#  'corralling': 1,
#  'cattle': 1,
#  'pickmeupanipad': 1,
#  'let': 21,
#  'something': 12,
#  'retail': 15,
#  'near': 9,
#  'keep': 34,
#  'surprise': 8,
#  'opened': 13,
#  'town': 11,
#  'cnet': 11,
#  'ipads': 39,
#  'example': 13,
#  'layed': 2,
#  'register': 4,
#  'checkout': 2,
#  'gswsxsw': 2,
#  'traffic': 29,
#  'noon': 1,
#  'fresh': 3,
#  'shipment': 3,
#  'pretty': 30,
#  'finger': 4,
#  'crossed': 1,
#  'technews': 3,
#  'save': 22,
#  'set': 50,
#  'news': 58,
#  'true': 13,
#  'loathe': 1,
#  'blog': 11,
#  'atx': 9,
#  'mall': 4,
#  'crowded': 4,
#  'fake': 1,
#  'fucking': 5,
#  'dongle': 1,
#  'makeshift': 8,
#  'kidding': 2,
#  'amazing': 33,
#  'fanboy': 7,
#  'shit': 12,
#  'temptation': 3,
#  'control': 8,
#  'growing': 3,
#  'view': 21,
#  'io': 17,
#  'office': 5,
#  'software': 6,
#  'development': 3,
#  'release': 28,
#  'working': 22,
#  'overheard': 3,
#  'relaxing': 1,
#  'computer': 9,
#  'agreed': 3,
#  'arg': 2,
#  'hate': 10,
#  'blackberry': 29,
#  'back': 38,
#  'shocked': 2,
#  'technology': 53,
#  'heard': 57,
#  'go': 117,
#  'everbody': 1,
#  'medium': 20,
#  'driven': 4,
#  'revolution': 2,
#  'better': 48,
#  'long': 35,
#  'work': 47,
#  'rather': 6,
#  'agileagency': 5,
#  'knackered': 1,
#  'playing': 14,
#  'updating': 1,
#  'timeline': 1,
#  'smashed': 1,
#  'partytweets': 1,
#  'bed': 2,
#  'mdw': 1,
#  'second': 8,
#  'halfway': 1,
#  'even': 78,
#  'boarded': 1,
#  'amateurhour': 1,
#  'co': 4,
#  'final': 4,
#  'doodle': 19,
#  'googledoodle': 9,
#  'crowd': 15,
#  'tripping': 1,
#  'aclu': 12,
#  'laughed': 1,
#  'week': 44,
#  'hauling': 1,
#  'macbook': 17,
#  'everywhere': 15,
#  'shoulder': 2,
#  'rub': 1,
#  'attendee': 26,
#  'qr': 3,
#  'code': 8,
#  'reader': 7,
#  'u': 63,
#  'image': 9,
#  'badge': 13,
#  'optiscan': 1,
#  'four': 5,
#  'took': 7,
#  'lego': 4,
#  'pit': 1,
#  'replaced': 2,
#  'recharging': 1,
#  'might': 17,
#  'price': 3,
#  'crap': 2,
#  'samsung': 5,
#  'bad': 16,
#  'q': 1,
#  'process': 2,
#  'poo': 1,
#  'poos': 1,
#  'leaf': 1,
#  'early': 13,
#  'creative': 5,
#  'busy': 8,
#  'gamestorming': 1,
#  'trying': 14,
#  'balance': 1,
#  'v': 20,
#  'airplane': 1,
#  'mode': 3,
#  'precommerce': 1,
#  'watch': 12,
#  'ipadmadness': 1,
#  'shop': 50,
#  'core': 17,
#  'action': 32,
#  'celebrate': 5,
#  'beauty': 2,
#  'web': 39,
#  'msft': 2,
#  'ie': 7,
#  'html': 10,
#  'gave': 19,
#  'money': 18,
#  'relief': 11,
#  'improve': 5,
#  'beyond': 8,
#  'sharing': 7,
#  'positive': 5,
#  'world': 43,
#  'download': 30,
#  'earthhour': 2,
#  'bing': 31,
#  'bettersearch': 3,
#  'shot': 8,
#  'success': 14,
#  'structured': 2,
#  'potentially': 2,
#  'higher': 4,
#  'margin': 2,
#  'cpa': 2,
#  'model': 9,
#  'result': 10,
#  'qagb': 13,
#  'impulsive': 3,
#  'friend': 31,
#  'gen': 4,
#  'gb': 11,
#  'buying': 12,
#  'geekdate': 2,
#  'present': 3,
#  'rsq': 1,
#  'tuxedo': 2,
#  'lose': 9,
#  'exciting': 6,
#  'certain': 1,
#  'meeting': 8,
#  'hello': 6,
#  'dont': 7,
#  'miss': 7,
#  'charles': 1,
#  'chen': 1,
#  'chromeos': 1,
#  'access': 2,
#  'booth': 29,
#  'exhibit': 6,
#  'hall': 8,
#  'guess': 16,
#  'desperate': 1,
#  'location': 37,
#  'considering': 1,
#  'leaving': 8,
#  'pro': 8,
#  'flying': 2,
#  'solo': 2,
#  'daily': 11,
#  'follow': 8,
#  'appleatxdt': 4,
#  'seems': 22,
#  'battlela': 1,
#  'secret': 4,
#  'batphone': 1,
#  'tv': 33,
#  'league': 5,
#  'extraordinary': 5,
#  'hacker': 5,
#  'lxh': 2,
#  'big': 51,
#  'chunky': 2,
#  'element': 2,
#  'generous': 2,
#  'clarity': 2,
#  'trump': 5,
#  'density': 2,
#  'tap': 4,
#  'quality': 3,
#  'quantity': 2,
#  'tapworthy': 31,
#  'designing': 12,
#  'interface': 18,
#  'schema': 3,
#  'lovin': 2,
#  'digital': 26,
#  'sings': 1,
#  'guitar': 2,
#  'record': 3,
#  'vids': 3,
#  'cnn': 13,
#  'cnngrill': 3,
#  'content': 20,
#  'nut': 4,
#  'another': 19,
#  'docomo': 1,
#  'introduced': 2,
#  'came': 4,
#  'jpmobilesummit': 1,
#  'jeez': 1,
#  'guy': 51,
#  'dunno': 1,
#  'gold': 6,
#  'realize': 3,
#  'un': 2,
#  'aesthetic': 1,
#  'begin': 45,
#  'tc': 6,
#  'techcrunch': 4,
#  'gon': 14,
#  'na': 14,
#  'sum': 2,
#  'badgeless': 2,
#  'drink': 18,
#  'heading': 23,
#  'semantic': 6,
#  'fogo': 4,
#  'de': 6,
#  'ch': 4,
#  'swag': 4,
#  'charging': 10,
#  'timing': 4,
#  'brand': 18,
#  'winner': 6,
#  'pnid': 9,
#  'exhibitor': 1,
#  'capture': 3,
#  'experience': 15,
#  'retrollect': 4,
#  'disc': 7,
#  'popular': 5,
#  'accessory': 3,
#  'followed': 1,
#  'closely': 2,
#  'margarita': 1,
#  'fav': 4,
#  'fell': 3,
#  'bit': 15,
#  'throwing': 4,
#  'speakeasy': 5,
#  'way': 47,
#  'figure': 5,
#  'replacement': 3,
#  'making': 16,
#  'stream': 17,
#  'inane': 1,
#  'surely': 4,
#  'southby': 2,
#  'hottest': 2,
#  'spot': 8,
#  'hot': 29,
#  'focusing': 2,
#  'bridging': 2,
#  'physical': 16,
#  'divide': 2,
#  'eg': 3,
#  'streetview': 3,
#  'hotpot': 21,
#  'autonomous': 2,
#  'folk': 12,
#  'posted': 1,
#  'blast': 1,
#  'bound': 5,
#  'fanboys': 4,
#  'list': 11,
#  'ntn': 1,
#  'help': 14,
#  'field': 4,
#  'kid': 11,
#  'hitlantis': 4,
#  'song': 17,
#  'explorer': 6,
#  'musicviz': 2,
#  'willing': 3,
#  'pick': 10,
#  'pay': 6,
#  'premium': 1,
#  'dm': 2,
#  'atl': 1,
#  'akqas': 2,
#  'callback': 2,
#  'principle': 4,
#  'person': 23,
#  'front': 12,
#  'outside': 16,
#  'word': 10,
#  'trending': 6,
#  'forget': 12,
#  'snap': 3,
#  'air': 7,
#  'getting': 38,
#  'full': 21,
#  'underway': 2,
#  'tell': 26,
#  'intermittent': 1,
#  'brick': 3,
#  'lab': 4,
#  'source': 4,
#  'coder': 1,
#  'cupcake': 1,
#  'window': 7,
#  'addition': 2,
#  'afraid': 1,
#  'omg': 13,
#  'ipod': 11,
#  'tab': 1,
#  'techgeek': 1,
#  'golden': 1,
#  'ticket': 3,
#  'redbullbpm': 1,
#  'felix': 1,
#  'da': 1,
#  'housecat': 1,
#  'gsd': 7,
#  'blowing': 1,
#  'much': 41,
#  'music': 36,
#  'alternative': 1,
#  'facebook': 15,
#  'site': 16,
#  'stand': 5,
#  'blocking': 1,
#  'length': 1,
#  'penalty': 1,
#  'based': 17,
#  'severity': 1,
#  'breach': 1,
#  'webmaster': 2,
#  'guideline': 1,
#  'text': 5,
#  'bgr': 1,
#  'pen': 3,
#  'called': 77,
#  'possibly': 49,
#  'never': 19,
#  'beat': 7,
#  'myspace': 1,
#  'bigger': 10,
#  'gaga': 1,
#  'super': 14,
#  'interesting': 30,
#  'applause': 2,
#  'privacy': 8,
#  'attempt': 2,
#  'contextual': 3,
#  'discovery': 6,
#  'context': 1,
#  'deeper': 1,
#  'without': 17,
#  'googletv': 3,
#  'connected': 7,
#  'connectedtv': 3,
#  'fascinating': 2,
#  'cnnmoney': 3,
#  'craving': 2,
#  'created': 2,
#  'foodspotting': 5,
#  'dude': 9,
#  'cutsies': 2,
#  'smtravel': 1,
#  'plan': 14,
#  'socnet': 1,
#  'learned': 3,
#  'lot': 36,
#  'invite': 5,
#  'two': 26,
#  'pocket': 5,
#  'lordy': 1,
#  'pulling': 3,
#  'trigger': 1,
#  'loved': 5,
#  'honesty': 1,
#  'product': 54,
#  'step': 10,
#  'customer': 16,
#  'service': 23,
#  'bout': 3,
#  'donating': 1,
#  'spending': 3,
#  'wondering': 4,
#  'revenue': 5,
#  'grossed': 1,
#  'account': 3,
#  ...}

# %%
# print max number of tokens in any row
rows = df.tokenl.astype(str)
maxlen=-1
for row in rows:
    tokens = row.split(',')
    token_cnt = len(tokens)
    
    longest_token = max(tokens)
    if(maxlen<len(tokens)):
        maxlen=len(tokens)

print("The maximum number of words in any document is : ",maxlen)
# Out:
# The maximum number of words in any document is :  18

# %% [markdown]
# ##  assess word frequency

# %%
from wordcloud import WordCloud

# %%
top_50(df.tokens)
top_50(df.tokenl)
# Out:
# 50 MOST common words: [('rt', 1063), ('store', 584), ('new', 394), ('get', 237), ('pop', 223), ('launch', 217), ('open', 185), ('go', 184), ('one', 168), ('line', 165), ('time', 164), ('use', 162), ('like', 159), ('parti', 159), ('circl', 158), ('come', 157), ('social', 155), ('win', 151), ('day', 147), ('great', 138), ('via', 134), ('today', 132), ('map', 125), ('cool', 122), ('free', 120), ('love', 118), ('look', 115), ('peopl', 111), ('network', 110), ('app', 108), ('good', 107), ('mobil', 107), ('check', 105), ('see', 105), ('awesom', 103), ('need', 97), ('got', 97), ('thank', 91), ('temporari', 89), ('call', 88), ('downtown', 86), ('year', 84), ('think', 84), ('design', 83), ('take', 82), ('make', 80), ('even', 80), ('user', 78), ('mayer', 76), ('first', 75)]
# Total: 4294
# 50 MOST common words: [('rt', 1063), ('store', 584), ('new', 394), ('pop', 219), ('get', 199), ('launch', 188), ('one', 168), ('line', 162), ('circle', 158), ('party', 156), ('time', 154), ('like', 152), ('social', 152), ('day', 147), ('great', 138), ('via', 134), ('today', 132), ('win', 122), ('map', 121), ('cool', 121), ('free', 120), ('go', 117), ('people', 111), ('come', 110), ('network', 108), ('apps', 108), ('mobile', 106), ('good', 103), ('need', 97), ('got', 97), ('love', 97), ('awesome', 93), ('opening', 89), ('temporary', 89), ('see', 89), ('check', 87), ('downtown', 86), ('year', 84), ('open', 83), ('going', 79), ('user', 78), ('look', 78), ('even', 78), ('think', 77), ('called', 77), ('mayer', 76), ('first', 75), ('thanks', 75), ('popup', 74), ('major', 73)]
# Total: 5056

# %%
pos_df = df[df['sentiment']=='positive']
neg_df = df[df['sentiment']=='negative']

# %%
top_50(pos_df.tokens)
top_50(pos_df.tokenl)
# Out:
# 50 MOST common words: [('rt', 927), ('store', 538), ('new', 353), ('pop', 206), ('get', 203), ('launch', 188), ('open', 176), ('go', 158), ('parti', 152), ('win', 149), ('one', 146), ('time', 142), ('line', 142), ('come', 139), ('use', 132), ('great', 130), ('day', 126), ('social', 125), ('circl', 123), ('via', 122), ('free', 118), ('cool', 118), ('like', 115), ('map', 115), ('today', 112), ('love', 111), ('awesom', 99), ('check', 99), ('mobil', 95), ('good', 93), ('network', 93), ('look', 91), ('got', 90), ('see', 90), ('downtown', 85), ('temporari', 84), ('thank', 83), ('peopl', 82), ('app', 82), ('make', 72), ('popup', 72), ('even', 71), ('call', 68), ('mayer', 67), ('year', 67), ('around', 65), ('first', 64), ('market', 64), ('user', 63), ('want', 63)]
# Total: 3700
# 50 MOST common words: [('rt', 927), ('store', 538), ('new', 353), ('pop', 203), ('get', 174), ('launch', 167), ('party', 150), ('one', 146), ('line', 140), ('time', 132), ('great', 130), ('day', 126), ('circle', 123), ('via', 122), ('social', 122), ('win', 120), ('free', 118), ('cool', 117), ('map', 112), ('today', 112), ('like', 109), ('go', 104), ('come', 101), ('mobile', 94), ('love', 91), ('network', 91), ('got', 90), ('awesome', 89), ('good', 89), ('opening', 86), ('downtown', 85), ('temporary', 84), ('check', 83), ('people', 82), ('apps', 82), ('open', 78), ('see', 74), ('popup', 72), ('even', 69), ('thanks', 68), ('mayer', 67), ('year', 67), ('going', 66), ('around', 65), ('first', 64), ('called', 64), ('user', 63), ('need', 62), ('marissa', 59), ('best', 59)]
# Total: 4333

# %%
pos_words = []
for t in pos_df.wordl:
    pos_words.append(t)
pos_text = pd.Series(pos_words).str.cat(sep=' ')

# %%
from wordcloud import WordCloud
wordcloud = WordCloud(width=1600, height=800, max_font_size=200).generate(pos_text)
plt.figure(figsize=(12,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
top_50(neg_df.tokens)
top_50(neg_df.tokenl)
# Out:
# 50 MOST common words: [('rt', 136), ('store', 46), ('like', 44), ('new', 41), ('need', 35), ('circl', 35), ('get', 34), ('social', 30), ('use', 30), ('design', 29), ('peopl', 29), ('launch', 29), ('go', 26), ('app', 26), ('think', 24), ('look', 24), ('line', 23), ('one', 22), ('time', 22), ('day', 21), ('would', 21), ('take', 21), ('say', 20), ('call', 20), ('today', 20), ('come', 18), ('phone', 18), ('fail', 18), ('year', 17), ('pop', 17), ('network', 17), ('talk', 17), ('headach', 16), ('long', 16), ('product', 16), ('tweet', 15), ('user', 15), ('wait', 15), ('news', 15), ('batteri', 15), ('thing', 15), ('see', 15), ('much', 15), ('compani', 15), ('america', 15), ('back', 14), ('tri', 14), ('money', 14), ('major', 14), ('realli', 14)]
# Total: 1628
# 50 MOST common words: [('rt', 136), ('store', 46), ('like', 43), ('new', 41), ('need', 35), ('circle', 35), ('social', 30), ('people', 29), ('design', 27), ('apps', 26), ('get', 25), ('think', 23), ('line', 22), ('one', 22), ('time', 22), ('launch', 21), ('day', 21), ('would', 21), ('look', 21), ('say', 20), ('today', 20), ('phone', 18), ('year', 17), ('network', 17), ('headache', 16), ('pop', 16), ('long', 16), ('product', 16), ('fail', 16), ('user', 15), ('news', 15), ('battery', 15), ('thing', 15), ('see', 15), ('much', 15), ('company', 15), ('america', 15), ('back', 14), ('money', 14), ('major', 14), ('really', 14), ('good', 14), ('fascist', 14), ('talk', 14), ('going', 13), ('already', 13), ('go', 13), ('called', 13), ('way', 13), ('take', 13)]
# Total: 1807

# %%
neg_words = []
for t in neg_df.wordl:
    neg_words.append(t)
neg_text = pd.Series(neg_words).str.cat(sep=' ')

# %%
wordcloud = WordCloud(width=1600, height=800, max_font_size=200).generate(neg_text)
plt.figure(figsize=(12,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
plt.figure(figsize=(11,11))
colors = ['lightblue', 'silver']
expl = (0, 0.1)
df.sentiment.value_counts().plot(kind='pie', legend=True, startangle=45, shadow=True, 
                             colors=colors, autopct='%1.1f%%')
plt.title('Sentiment Count', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Sentiment Count')

# %% [markdown]
# # model

# %%
# import modules for model
from io import StringIO
import random
from keras.utils.np_utils import to_categorical
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from tensorflow import keras
from keras.preprocessing.text import Tokenizer
from keras import models
from keras import layers
from keras import optimizers
from keras.models import Sequential
from keras import callbacks
from keras import initializers
from keras.regularizers import l2
from keras.layers import Dense , Flatten ,Embedding, Input
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer, TfidfTransformer
from imblearn.over_sampling import SMOTE
from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix
from sklearn.decomposition import PCA
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
import gensim
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## functions

# %%
def display_results(y_test, y_pred):
    labels = np.unique(y_pred)
    confusion_mat = confusion_matrix(y_test, y_pred, labels=labels)
    accuracy = (y_pred == y_test).mean()

    print("Labels:", labels)
    print("Confusion Matrix:\n", confusion_mat)
    print("Accuracy:", accuracy)

# %%
def acc_loss_plot(model_dict):
    acc_values = model_dict['accuracy']
    loss_values =model_dict['loss']

    epochs = range(1, len(loss_values) + 1)

    # Plot the training loss vs the number of epochs
    plt.figure(figsize=(12,9))
    plt.plot(epochs, loss_values, 'b', label='Training loss')

    plt.title('Training loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()


    # Plot the training accuracy vs the number of epochs
    plt.figure(figsize=(12,9))
    plt.plot(epochs, acc_values, 'r', label='Training acc')


    plt.title('Training accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')

    plt.show()

# %% [markdown]
# ## PCA data visualization

# %%
# plot PCA visualization of tokens

g_plot = df.copy()
col = ['wordl', 'sentiment']
g_plot = g_plot[col]
X_p = g_plot['wordl']
y_p = g_plot['sentiment']


pipeline = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
])        
Xp = pipeline.fit_transform(X_p).todense()

pca = PCA(n_components=2).fit(Xp)
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(Xp)

principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])


finalDf = pd.concat([principalDf, g_plot[['sentiment']]], axis = 1)

fig = plt.figure(figsize = (18,12))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = ['positive', 'negative']
colors = ['r', 'b']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['sentiment'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'principal component 1']
               , finalDf.loc[indicesToKeep, 'principal component 2']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

# %% [markdown]
# ## transform data from strings to numeric data

# %%
# define countvectorizer
cvec = CountVectorizer(ngram_range=(1,2))
cvec.fit(df.wordl)
# create countvectors for sentiments
neg_matrix = cvec.transform(df[df.sentiment == 'negative'].wordl)

pos_matrix = cvec.transform(df[df.sentiment == 'positive'].wordl)


neg_words = neg_matrix.sum(axis=0)
neg_words_freq = [(word, neg_words[0, idx]) for word, idx in cvec.vocabulary_.items()]
neg_tf = pd.DataFrame(list(sorted(neg_words_freq, key = lambda x: x[1], reverse=True)),columns=['token','negative'])

neg_tf_df = neg_tf.set_index('token')

pos_words = pos_matrix.sum(axis=0)
pos_words_freq = [(word, pos_words[0, idx]) for word, idx in cvec.vocabulary_.items()]
pos_words_tf = pd.DataFrame(list(sorted(pos_words_freq, key = lambda x: x[1], reverse=True)),columns=['token','positive'])
pos_tf_df = pos_words_tf.set_index('token')

# %%
neg_tf_df.head()
# Out:
#        negative
# token
# rt          136
# store        46
# like         43
# new          41
# need         35

# %%
term_freq_df = pd.concat([neg_tf_df ,pos_tf_df],axis=1)

term_freq_df['total'] = term_freq_df['negative'] +  term_freq_df['positive']
        
term_freq_df.sort_values(by='total', ascending=False).head(15)
# Out:
#            negative  positive  total
# rt              136       927   1063
# store            46       538    584
# new              41       353    394
# pop              16       203    219
# get              25       174    199
# launch           21       167    188
# pop store        11       157    168
# one              22       146    168
# line             22       140    162
# circle           35       123    158
# party             6       150    156
# time             22       132    154
# like             43       109    152
# social           30       122    152
# day              21       126    147

# %% [markdown]
# # initially i transformed my data before the train test split, these are the results

# %% [markdown]
# ## prepare data for model

# %%
# convert target data with labelencoder
y1 = df.num_sentiment.astype('category')
le = LabelEncoder()
y = le.fit_transform(y1)
y
# Out:
# array([0, 1, 1, ..., 0, 1, 1])

# %%
X1 = df.wordl.copy()

# %%
# build TFIDF features on train reviews
ttv = TfidfVectorizer(min_df=0.0, max_df=1.0, ngram_range=(1,2), use_idf=True
                     )
Xtfv = ttv.fit_transform(X1)
xdf = pd.DataFrame(Xtfv[0].T.todense(),
index=ttv.get_feature_names(), columns=["term"])
xdf = xdf.sort_values('term', ascending=False)
print (xdf.head(25))
# Out:
#                      term
# rise dead        0.278078
# dead need        0.278078
# upgrade plugin   0.278078
# tweeting rise    0.278078
# hr tweeting      0.278078
# plugin station   0.278078
# need upgrade     0.268117
# plugin           0.260390
# station          0.260390
# dead             0.260390
# hr               0.260390
# rise             0.244116
# upgrade          0.240037
# tweeting         0.224738
# need             0.158802
# pulling article  0.000000
# purchase smooth  0.000000
# pumped need      0.000000
# pumped           0.000000
# pulling trigger  0.000000
# pun intended     0.000000
# puppy            0.000000
# puppy anywhere   0.000000
# pump lava        0.000000
# pump             0.000000

# %%
# split data 
X_train, X_test, y_train, y_test = train_test_split(Xtfv, y, random_state=42,
                                                     test_size=.2, stratify=y)

# %% [markdown]
# ## apply smote to target data due to unbalanced data

# %%
# verify shape of data
print('Test label shape:', np.shape(y_test))
print('Train label shape:', np.shape(y_train))
print('Test shape:', np.shape(X_test))
print('Train shape:', np.shape(X_train))
# Out:
# Test label shape: (679,)
# Train label shape: (2713,)
# Test shape: (679, 21326)
# Train shape: (2713, 21326)

# %%
# summarize the  class distribution
counter = Counter(y_train)
print(counter)
# Out:
# Counter({1: 2279, 0: 434})

# %%
# apply smote to dataset due to imbalance of pos vs neg sentiment
sm = SMOTE(random_state=42)
X_train, y_train = sm.fit_resample(X_train, y_train)

# summarize the new class distribution
counter = Counter(y_train)
print(counter)
# Out:
# Counter({1: 2279, 0: 2279})

# %%
# verify new shape of data
print('Test label shape:', np.shape(y_test))
print('Train label shape:', np.shape(y_train))
print('Test shape:', np.shape(X_test))
print('Train shape:', np.shape(X_train))

#assign variable to np.shape tuple, width dimension
input_dimension = np.shape(X_train)
count_terms = input_dimension[1]
# Out:
# Test label shape: (679,)
# Train label shape: (4558,)
# Test shape: (679, 21326)
# Train shape: (4558, 21326)

# %%
# initializers 
initializer = keras.initializers.he_normal(seed=1)
initializer2 = keras.initializers.glorot_normal(seed=1)

# regularizer to minimize overfitting
regularizer = keras.regularizers.l2(0.001)
# Out:
# WARNING:tensorflow:From /Users/badmin/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:1288: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %% [markdown]
# ##  ~~nn model #1~~

# %%
# create pyramid shaped sequential model
model = models.Sequential()

# activation layer 
model.add(layers.Dense(300, input_dim=count_terms, activation='relu', 
                       kernel_initializer=initializer, trainable =True))

model.add(layers.BatchNormalization(momentum=0.9, trainable =True))

# add relu activated hidden layers
model.add(layers.Dense(64, activation='relu', 
                       kernel_initializer=initializer))   


# output layer with sigmoid activation for binary target
model.add(layers.Dense(1, activation='sigmoid'))

# %%
# Compile the model
# early stopping callback to prevent overfitting
es_callback = keras.callbacks.EarlyStopping(monitor='loss', patience=10)
# best model callback 
bm_callback = keras.callbacks.ModelCheckpoint("best_model.h5",
                                             save_best_only=True)
#define optimizer and learningrate/learning rate as default for this model
lr = 0.001
sgd_opt = optimizers.SGD(lr=lr, nesterov=True)
nad_opt = optimizers.Nadam(lr=lr, beta_1=0.9, beta_2=0.999)
# use bce loss function for binary classification 
model.compile(optimizer=nad_opt, loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /Users/badmin/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
# Train the model 
history1 = model.fit(X_train,
                    y_train,
                    epochs=100,
                    callbacks=[es_callback],
                    batch_size=72,
                    )
# Out:
# WARNING:tensorflow:From /Users/badmin/opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/100
# 4558/4558 [==============================] - 7s 2ms/step - loss: 0.1715 - accuracy: 0.9384
# Epoch 2/100
# 4558/4558 [==============================] - 7s 2ms/step - loss: 0.0408 - accuracy: 0.9857
# Epoch 3/100
# 4558/4558 [==============================] - 7s 2ms/step - loss: 0.0132 - accuracy: 0.9950
# Epoch 4/100
# 4558/4558 [==============================] - 7s 2ms/step - loss: 0.0077 - accuracy: 0.9969
# Epoch 5/100
# 4558/4558 [==============================] - 7s 2ms/step - loss: 0.0056 - accuracy: 0.9982
# Epoch 6/100
# 4558/4558 [==============================] - 7s 2ms/step - loss: 0.0061 - accuracy: 0.9974
# Epoch 7/100
# 4558/4558 [==============================] - 7s 2ms/step - loss: 0.0058 - accuracy: 0.9982
# Epoch 8/100
# 4558/4558 [==============================] - 7s 2ms/step - loss: 0.0039 - accuracy: 0.9980
# Epoch 9/100
# 4558/4558 [==============================] - 7s 2ms/step - loss: 0.0024 - accuracy: 0.9993
# Epoch 10/100
# 4558/4558 [==============================] - 7s 2ms/step - loss: 0.0033 - accuracy: 0.9987
# Epoch 11/100
# 4558/4558 [==============================] - 7s 2ms/step - loss: 0.0017 - accuracy: 0.9991
# Epoch 12/100
# 4558/4558 [==============================] - 7s 2ms/step - loss: 0.0025 - accuracy: 0.9980
# Epoch 13/100
# 4558/4558 [==============================] - 7s 2ms/step - loss: 0.0025 - accuracy: 0.9987
# Epoch 14/100
# 4558/4558 [==============================] - 7s 2ms/step - loss: 0.0039 - accuracy: 0.9987
# Epoch 15/100
# 4558/4558 [==============================] - 7s 2ms/step - loss: 0.0076 - accuracy: 0.9969
# Epoch 16/100
# 4558/4558 [==============================] - 7s 2ms/step - loss: 0.0190 - accuracy: 0.9954
# Epoch 17/100
# 4558/4558 [==============================] - 7s 2ms/step - loss: 0.0131 - accuracy: 0.9954
# Epoch 18/100
# 4558/4558 [==============================] - 7s 2ms/step - loss: 0.0046 - accuracy: 0.9989
# Epoch 19/100
# 4558/4558 [==============================] - 7s 2ms/step - loss: 0.0017 - accuracy: 0.9993
# Epoch 20/100
# 4558/4558 [==============================] - 7s 2ms/step - loss: 0.0014 - accuracy: 0.9993
# Epoch 21/100
# 4558/4558 [==============================] - 7s 2ms/step - loss: 0.0012 - accuracy: 0.9991
# Epoch 22/100
# 4558/4558 [==============================] - 7s 2ms/step - loss: 0.0026 - accuracy: 0.9991
# Epoch 23/100
# 4558/4558 [==============================] - 7s 2ms/step - loss: 0.0018 - accuracy: 0.9989
# Epoch 24/100
# 4558/4558 [==============================] - 7s 2ms/step - loss: 0.0014 - accuracy: 0.9993
# Epoch 25/100
# 4558/4558 [==============================] - 7s 2ms/step - loss: 0.0011 - accuracy: 0.9996
# Epoch 26/100
# 4558/4558 [==============================] - 7s 2ms/step - loss: 0.0016 - accuracy: 0.9993
# Epoch 27/100
# 4558/4558 [==============================] - 7s 2ms/step - loss: 0.0019 - accuracy: 0.9989
# Epoch 28/100
# 4558/4558 [==============================] - 7s 2ms/step - loss: 0.0013 - accuracy: 0.9996
# Epoch 29/100
# 4558/4558 [==============================] - 7s 2ms/step - loss: 0.0025 - accuracy: 0.9991
# Epoch 30/100
# 4558/4558 [==============================] - 7s 2ms/step - loss: 0.0025 - accuracy: 0.9989
# Epoch 31/100
# 4558/4558 [==============================] - 7s 2ms/step - loss: 0.0035 - accuracy: 0.9987
# Epoch 32/100
# 4558/4558 [==============================] - 7s 2ms/step - loss: 0.0022 - accuracy: 0.9991
# Epoch 33/100
# 4558/4558 [==============================] - 7s 2ms/step - loss: 0.0012 - accuracy: 0.9998
# Epoch 34/100
# 4558/4558 [==============================] - 7s 2ms/step - loss: 0.0012 - accuracy: 0.9993
# Epoch 35/100
# 4558/4558 [==============================] - 7s 2ms/step - loss: 0.0023 - accuracy: 0.9993

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 300)               6398100
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 300)               1200
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                19264
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 6,418,629
# Trainable params: 6,418,029
# Non-trainable params: 600
# _________________________________________________________________

# %%
model1_dict = history1.history
model1_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy'])

# %%
acc_loss_plot(model1_dict)

# %%
# Print the loss and accuracy for the training set 
model.evaluate(X_train, y_train)
# Out:
# 4558/4558 [==============================] - 1s 168us/step
# [0.000983299430045535, 0.9993418455123901]

# %%
# Print the loss and accuracy for the test set 
results_test = model.evaluate(X_test, y_test)
results_test
# Out:
# 679/679 [==============================] - 0s 170us/step
# [1.763346752116185, 0.8703976273536682]

# %%
# predict probabilities for test set
yhat_probs = model.predict(X_test, verbose=0)
# predict crisp classes for test set
yhat_classes = model.predict_classes(X_test, verbose=0)

# reduce to 1d array
yhat_probs = yhat_probs[:, 0]
yhat_classes = yhat_classes[:, 0]

# %% [markdown]
# ### assess metrics for model

# %%
# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(y_test, yhat_classes)
print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp)
precision = precision_score(y_test, yhat_classes)
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(y_test, yhat_classes)
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_test, yhat_classes)
print('F1 score: %f' % f1)
# kappa
kappa = cohen_kappa_score(y_test, yhat_classes)
print('Cohens kappa: %f' % kappa)
# ROC AUC
auc = roc_auc_score(y_test, yhat_probs)
print('ROC AUC: %f' % auc)
# confusion matrix
matrix = confusion_matrix(y_test, yhat_classes)
print(matrix)
# Out:
# Accuracy: 0.870398
# Precision: 0.870769
# Recall: 0.992982
# F1 score: 0.927869
# Cohens kappa: 0.316182
# ROC AUC: 0.789007
# [[ 25  84]
#  [  4 566]]

# %% [markdown]
# # realizing my mistake, I corrected and applied tfidf vector fit and transformation on training set then transformed test set accordingly to prevent leakage

# %% [markdown]
# ## prepare data for model

# %%
# convert target data with labelencoder
y1 = df.num_sentiment.astype('category')
le = LabelEncoder()
y = le.fit_transform(y1)
y
# Out:
# array([0, 1, 1, ..., 0, 1, 1])

# %%
X = df.wordl

# split data 
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,
                                                     test_size=.2, stratify=y)

# %%
# build TFIDF features on tweet with

tfv = TfidfVectorizer(min_df=0.0, max_df=1.0, ngram_range=(1,2), use_idf=True
                     )
X_train_trans = tfv.fit_transform(X_train)
xdf = pd.DataFrame(X_train_trans[0].T.todense(),
index=tfv.get_feature_names(), columns=["term"])
xdf = xdf.sort_values('term', ascending=False)
print (xdf.head(25))

test_features = tfv.transform(X_test)
X_train = X_train_trans.copy()
X_test = test_features.copy()
# Out:
#                          term
# feature saving       0.253802
# map feature          0.253802
# day holytrafficjams  0.253802
# holytrafficjams      0.253802
# traffic map          0.244450
# rt route             0.244450
# time every           0.226259
# saving user          0.221918
# year time            0.218089
# user year            0.208737
# every day            0.203726
# around traffic       0.201484
# saving               0.197415
# feature              0.192132
# traffic              0.192132
# route around         0.190546
# route                0.184878
# every                0.173025
# around               0.158086
# year                 0.156965
# user                 0.154833
# map                  0.142524
# day                  0.136715
# time                 0.133617
# rt                   0.073927

# %% [markdown]
# ## apply smote to target data due to unbalanced data

# %%
# verify shape of data
print('Test label shape:', np.shape(y_test))
print('Train label shape:', np.shape(y_train))
print('Test shape:', np.shape(X_test))
print('Train shape:', np.shape(X_train))
# Out:
# Test label shape: (679,)
# Train label shape: (2713,)
# Test shape: (679, 18251)
# Train shape: (2713, 18251)

# %%
# summarize the  class distribution
counter = Counter(y_train)
print(counter)
# Out:
# Counter({1: 2279, 0: 434})

# %%
# apply smote to dataset due to imbalance of pos vs neg sentiment
sm = SMOTE(random_state=42)
X_train, y_train = sm.fit_resample(X_train, y_train)

# summarize the new class distribution
counter = Counter(y_train)
print(counter)
# Out:
# Counter({1: 2279, 0: 2279})

# %%
# verify new shape of data
print('Test label shape:', np.shape(y_test))
print('Train label shape:', np.shape(y_train))
print('Test shape:', np.shape(X_test))
print('Train shape:', np.shape(X_train))


#assign variable to np.shape tuple, width dimension
input_dimension = np.shape(X_train)
count_terms = input_dimension[1]
# Out:
# Test label shape: (679,)
# Train label shape: (4558,)
# Test shape: (679, 18251)
# Train shape: (4558, 18251)

# %% [markdown]
# ## nn model #1

# %%
# create pyramid shaped sequential model
model1 = models.Sequential()

# activation layer 
model1.add(layers.Dense(300, input_dim=count_terms, activation='relu', 
                       kernel_initializer=initializer))

model1.add(layers.BatchNormalization(momentum=0.9))

# add relu activated hidden layers
model1.add(layers.Dense(64, activation='relu', 
                       kernel_initializer=initializer))   


# output layer with sigmoid activation for binary target
model1.add(layers.Dense(1, activation='sigmoid'))

# %%
# Compile the model
# early stopping callback to prevent overfitting
es_callback = keras.callbacks.EarlyStopping(monitor='loss', patience=10)
# best model callback 
bm_callback = keras.callbacks.ModelCheckpoint("best_model.h5",
                                             save_best_only=True)
#define optimizer and learningrate/learning rate as default for this model
lr = 0.001
sgd_opt = optimizers.SGD(lr=lr, nesterov=True)
nad_opt = optimizers.Nadam(lr=lr, beta_1=0.9, beta_2=0.999)
# use bce loss function for binary classification 
model1.compile(optimizer=sgd_opt, loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model 
predictions1 = model1.fit(X_train,
                    y_train,
                    epochs=100,
                    callbacks=[es_callback],
                    batch_size=72,
                    )
# Out:
# Epoch 1/100
# 4558/4558 [==============================] - 4s 871us/step - loss: 0.7087 - accuracy: 0.5090
# Epoch 2/100
# 4558/4558 [==============================] - 4s 829us/step - loss: 0.6900 - accuracy: 0.5323
# Epoch 3/100
# 4558/4558 [==============================] - 4s 833us/step - loss: 0.6737 - accuracy: 0.5542
# Epoch 4/100
# 4558/4558 [==============================] - 4s 826us/step - loss: 0.6587 - accuracy: 0.5838
# Epoch 5/100
# 4558/4558 [==============================] - 4s 829us/step - loss: 0.6446 - accuracy: 0.6095
# Epoch 6/100
# 4558/4558 [==============================] - 4s 828us/step - loss: 0.6310 - accuracy: 0.6433
# Epoch 7/100
# 4558/4558 [==============================] - 4s 834us/step - loss: 0.6179 - accuracy: 0.6711
# Epoch 8/100
# 4558/4558 [==============================] - 4s 836us/step - loss: 0.6043 - accuracy: 0.6996
# Epoch 9/100
# 4558/4558 [==============================] - 4s 831us/step - loss: 0.5929 - accuracy: 0.7277
# Epoch 10/100
# 4558/4558 [==============================] - 4s 839us/step - loss: 0.5802 - accuracy: 0.7543
# Epoch 11/100
# 4558/4558 [==============================] - 4s 857us/step - loss: 0.5687 - accuracy: 0.7749
# Epoch 12/100
# 4558/4558 [==============================] - 4s 876us/step - loss: 0.5566 - accuracy: 0.7986
# Epoch 13/100
# 4558/4558 [==============================] - 4s 941us/step - loss: 0.5453 - accuracy: 0.8190
# Epoch 14/100
# 4558/4558 [==============================] - 4s 844us/step - loss: 0.5340 - accuracy: 0.8376
# Epoch 15/100
# 4558/4558 [==============================] - 4s 903us/step - loss: 0.5239 - accuracy: 0.8480
# Epoch 16/100
# 4558/4558 [==============================] - 4s 819us/step - loss: 0.5120 - accuracy: 0.8706
# Epoch 17/100
# 4558/4558 [==============================] - 4s 826us/step - loss: 0.5004 - accuracy: 0.8850
# Epoch 18/100
# 4558/4558 [==============================] - 4s 827us/step - loss: 0.4898 - accuracy: 0.8964
# Epoch 19/100
# 4558/4558 [==============================] - 5s 1ms/step - loss: 0.4782 - accuracy: 0.9063
# Epoch 20/100
# 4558/4558 [==============================] - 5s 1ms/step - loss: 0.4683 - accuracy: 0.9142
# Epoch 21/100
# 4558/4558 [==============================] - 4s 871us/step - loss: 0.4565 - accuracy: 0.9247
# Epoch 22/100
# 4558/4558 [==============================] - 4s 854us/step - loss: 0.4471 - accuracy: 0.9326
# Epoch 23/100
# 4558/4558 [==============================] - 4s 875us/step - loss: 0.4364 - accuracy: 0.9388
# Epoch 24/100
# 4558/4558 [==============================] - 4s 917us/step - loss: 0.4248 - accuracy: 0.9454
# Epoch 25/100
# 4558/4558 [==============================] - 4s 896us/step - loss: 0.4151 - accuracy: 0.9491
# Epoch 26/100
# 4558/4558 [==============================] - 4s 900us/step - loss: 0.4045 - accuracy: 0.9548
# Epoch 27/100
# 4558/4558 [==============================] - 4s 855us/step - loss: 0.3954 - accuracy: 0.9572
# Epoch 28/100
# 4558/4558 [==============================] - 4s 838us/step - loss: 0.3838 - accuracy: 0.9609
# Epoch 29/100
# 4558/4558 [==============================] - 4s 841us/step - loss: 0.3757 - accuracy: 0.9631
# Epoch 30/100
# 4558/4558 [==============================] - 4s 848us/step - loss: 0.3647 - accuracy: 0.9656
# Epoch 31/100
# 4558/4558 [==============================] - 4s 846us/step - loss: 0.3562 - accuracy: 0.9699
# Epoch 32/100
# 4558/4558 [==============================] - 4s 852us/step - loss: 0.3460 - accuracy: 0.9713
# Epoch 33/100
# 4558/4558 [==============================] - 4s 850us/step - loss: 0.3381 - accuracy: 0.9746
# Epoch 34/100
# 4558/4558 [==============================] - 4s 841us/step - loss: 0.3268 - accuracy: 0.9765
# Epoch 35/100
# 4558/4558 [==============================] - 4s 893us/step - loss: 0.3194 - accuracy: 0.9735
# Epoch 36/100
# 4558/4558 [==============================] - 4s 954us/step - loss: 0.3093 - accuracy: 0.9785
# Epoch 37/100
# 4558/4558 [==============================] - 4s 790us/step - loss: 0.3009 - accuracy: 0.9805
# Epoch 38/100
# 4558/4558 [==============================] - 4s 794us/step - loss: 0.2933 - accuracy: 0.9818
# Epoch 39/100
# 4558/4558 [==============================] - 4s 809us/step - loss: 0.2871 - accuracy: 0.9814
# Epoch 40/100
# 4558/4558 [==============================] - 4s 788us/step - loss: 0.2751 - accuracy: 0.9846
# Epoch 41/100
# 4558/4558 [==============================] - 4s 931us/step - loss: 0.2689 - accuracy: 0.9838
# Epoch 42/100
# 4558/4558 [==============================] - 4s 954us/step - loss: 0.2605 - accuracy: 0.98570s - los
# Epoch 43/100
# 4558/4558 [==============================] - 4s 895us/step - loss: 0.2522 - accuracy: 0.9875
# Epoch 44/100
# 4558/4558 [==============================] - 4s 858us/step - loss: 0.2465 - accuracy: 0.9862
# Epoch 45/100
# 4558/4558 [==============================] - 4s 845us/step - loss: 0.2397 - accuracy: 0.9873
# Epoch 46/100
# 4558/4558 [==============================] - 4s 836us/step - loss: 0.2330 - accuracy: 0.9875
# Epoch 47/100
# 4558/4558 [==============================] - 4s 859us/step - loss: 0.2249 - accuracy: 0.9899
# Epoch 48/100
# 4558/4558 [==============================] - 4s 874us/step - loss: 0.2195 - accuracy: 0.9908
# Epoch 49/100
# 4558/4558 [==============================] - 4s 875us/step - loss: 0.2124 - accuracy: 0.9908
# Epoch 50/100
# 4558/4558 [==============================] - 4s 835us/step - loss: 0.2076 - accuracy: 0.9925
# Epoch 51/100
# 4558/4558 [==============================] - 4s 834us/step - loss: 0.2016 - accuracy: 0.9910
# Epoch 52/100
# 4558/4558 [==============================] - 4s 825us/step - loss: 0.1946 - accuracy: 0.9910
# Epoch 53/100
# 4558/4558 [==============================] - 4s 827us/step - loss: 0.1884 - accuracy: 0.9925
# Epoch 54/100
# 4558/4558 [==============================] - 4s 816us/step - loss: 0.1830 - accuracy: 0.9917
# Epoch 55/100
# 4558/4558 [==============================] - 4s 821us/step - loss: 0.1784 - accuracy: 0.9939
# Epoch 56/100
# 4558/4558 [==============================] - 4s 821us/step - loss: 0.1726 - accuracy: 0.9934
# Epoch 57/100
# 4558/4558 [==============================] - 4s 815us/step - loss: 0.1708 - accuracy: 0.9923
# Epoch 58/100
# 4558/4558 [==============================] - 4s 822us/step - loss: 0.1641 - accuracy: 0.9939
# Epoch 59/100
# 4558/4558 [==============================] - 4s 819us/step - loss: 0.1598 - accuracy: 0.9941
# Epoch 60/100
# 4558/4558 [==============================] - 4s 825us/step - loss: 0.1547 - accuracy: 0.9941
# Epoch 61/100
# 4558/4558 [==============================] - 4s 826us/step - loss: 0.1516 - accuracy: 0.9934
# Epoch 62/100
# 4558/4558 [==============================] - 4s 824us/step - loss: 0.1495 - accuracy: 0.9934
# Epoch 63/100
# 4558/4558 [==============================] - 4s 829us/step - loss: 0.1417 - accuracy: 0.9961
# Epoch 64/100
# 4558/4558 [==============================] - 4s 824us/step - loss: 0.1377 - accuracy: 0.9961
# Epoch 65/100
# 4558/4558 [==============================] - 4s 820us/step - loss: 0.1355 - accuracy: 0.9956
# Epoch 66/100
# 4558/4558 [==============================] - 4s 818us/step - loss: 0.1309 - accuracy: 0.9958
# Epoch 67/100
# 4558/4558 [==============================] - 4s 813us/step - loss: 0.1260 - accuracy: 0.9965
# Epoch 68/100
# 4558/4558 [==============================] - 4s 818us/step - loss: 0.1256 - accuracy: 0.9954
# Epoch 69/100
# 4558/4558 [==============================] - 4s 827us/step - loss: 0.1205 - accuracy: 0.9958
# Epoch 70/100
# 4558/4558 [==============================] - 4s 823us/step - loss: 0.1181 - accuracy: 0.9967
# Epoch 71/100
# 4558/4558 [==============================] - 4s 825us/step - loss: 0.1155 - accuracy: 0.9954
# Epoch 72/100
# 4558/4558 [==============================] - 4s 826us/step - loss: 0.1112 - accuracy: 0.9965
# Epoch 73/100
# 4558/4558 [==============================] - 4s 822us/step - loss: 0.1079 - accuracy: 0.9974
# Epoch 74/100
# 4558/4558 [==============================] - 4s 830us/step - loss: 0.1063 - accuracy: 0.9965
# Epoch 75/100
# 4558/4558 [==============================] - 4s 821us/step - loss: 0.1028 - accuracy: 0.9961
# Epoch 76/100
# 4558/4558 [==============================] - 4s 814us/step - loss: 0.1007 - accuracy: 0.9971
# Epoch 77/100
# 4558/4558 [==============================] - 4s 824us/step - loss: 0.0985 - accuracy: 0.9967
# Epoch 78/100
# 4558/4558 [==============================] - 4s 821us/step - loss: 0.0967 - accuracy: 0.9969
# Epoch 79/100
# 4558/4558 [==============================] - 4s 827us/step - loss: 0.0955 - accuracy: 0.9965
# Epoch 80/100
# 4558/4558 [==============================] - 4s 825us/step - loss: 0.0920 - accuracy: 0.9963
# Epoch 81/100
# 4558/4558 [==============================] - 4s 824us/step - loss: 0.0883 - accuracy: 0.9976
# Epoch 82/100
# 4558/4558 [==============================] - 4s 838us/step - loss: 0.0866 - accuracy: 0.9978
# Epoch 83/100
# 4558/4558 [==============================] - 4s 832us/step - loss: 0.0856 - accuracy: 0.9969
# Epoch 84/100
# 4558/4558 [==============================] - 4s 829us/step - loss: 0.0839 - accuracy: 0.9974
# Epoch 85/100
# 4558/4558 [==============================] - 4s 822us/step - loss: 0.0800 - accuracy: 0.9980
# Epoch 86/100
# 4558/4558 [==============================] - 4s 821us/step - loss: 0.0812 - accuracy: 0.9978
# Epoch 87/100
# 4558/4558 [==============================] - 4s 824us/step - loss: 0.0769 - accuracy: 0.9978
# Epoch 88/100
# 4558/4558 [==============================] - 4s 823us/step - loss: 0.0765 - accuracy: 0.9976
# Epoch 89/100
# 4558/4558 [==============================] - 4s 832us/step - loss: 0.0740 - accuracy: 0.9976
# Epoch 90/100
# 4558/4558 [==============================] - 4s 829us/step - loss: 0.0738 - accuracy: 0.9982
# Epoch 91/100
# 4558/4558 [==============================] - 4s 822us/step - loss: 0.0693 - accuracy: 0.9982
# Epoch 92/100
# 4558/4558 [==============================] - 4s 820us/step - loss: 0.0693 - accuracy: 0.9985
# Epoch 93/100
# 4558/4558 [==============================] - 4s 829us/step - loss: 0.0689 - accuracy: 0.9985
# Epoch 94/100
# 4558/4558 [==============================] - 4s 827us/step - loss: 0.0674 - accuracy: 0.9978
# Epoch 95/100
# 4558/4558 [==============================] - 4s 826us/step - loss: 0.0664 - accuracy: 0.9987
# Epoch 96/100
# 4558/4558 [==============================] - 4s 834us/step - loss: 0.0640 - accuracy: 0.9982
# Epoch 97/100
# 4558/4558 [==============================] - 4s 827us/step - loss: 0.0626 - accuracy: 0.9985
# Epoch 98/100
# 4558/4558 [==============================] - 4s 838us/step - loss: 0.0617 - accuracy: 0.9985
# Epoch 99/100
# 4558/4558 [==============================] - 4s 828us/step - loss: 0.0601 - accuracy: 0.9985
# Epoch 100/100
# 4558/4558 [==============================] - 4s 829us/step - loss: 0.0591 - accuracy: 0.9982

# %%
model1.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 300)               5475600
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 300)               1200
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                19264
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 5,496,129
# Trainable params: 5,495,529
# Non-trainable params: 600
# _________________________________________________________________

# %%
m1_dict =  predictions1.history
m1_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy'])

# %%
acc_loss_plot(m1_dict)

# %%
weights, biases = model1.layers[0].get_weights()

print('Weights:\n', weights)
print()
print('Biases:\n', biases)

# %%
# Print the loss and accuracy for the training set 
model1.evaluate(X_train, y_train)
# Out:
# 4558/4558 [==============================] - 1s 158us/step
# [0.05359101241528857, 0.9986836314201355]

# %%
# Print the loss and accuracy for the test set 
results_test = model1.evaluate(X_test, y_test)
results_test
# Out:
# 679/679 [==============================] - 0s 161us/step
# [0.3491935295893623, 0.861561119556427]

# %%
# predict probabilities for test set
yhat_probs = model1.predict(X_test, verbose=0)
# predict crisp classes for test set
yhat_classes = model1.predict_classes(X_test, verbose=0)

# reduce to 1d array
yhat_probs = yhat_probs[:, 0]

# %%
# assess metrics of model

# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(y_test, yhat_classes)
print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp)
precision = precision_score(y_test, yhat_classes)
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(y_test, yhat_classes)
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_test, yhat_classes)
print('F1 score: %f' % f1)
# kappa
kappa = cohen_kappa_score(y_test, yhat_classes)
print('Cohens kappa: %f' % kappa)
# ROC AUC
auc = roc_auc_score(y_test, yhat_probs)
print('ROC AUC: %f' % auc)
# confusion matrix
matrix = confusion_matrix(y_test, yhat_classes)
print(matrix)
# Out:
# Accuracy: 0.861561
# Precision: 0.896667
# Recall: 0.943860
# F1 score: 0.919658
# Cohens kappa: 0.422023
# ROC AUC: 0.820240
# [[ 47  62]
#  [ 32 538]]

# %%
# create pyramid shaped sequential model
model1_2 = models.Sequential()

# activation layer 
model1_2.add(layers.Dense(300, input_dim=count_terms, activation='relu', 
                       kernel_regularizer=regularizer))

model1_2.add(layers.BatchNormalization(momentum=0.9))

# add relu activated hidden layers
model1_2.add(layers.Dense(64, activation='relu', 
                       kernel_initializer=initializer))   


# output layer with sigmoid activation for binary target
model1_2.add(layers.Dense(1, activation='sigmoid'))
lr = 0.0001
sgd_opt = optimizers.SGD(lr=lr, nesterov=True)
nad_opt = optimizers.Nadam(lr=lr, beta_1=0.9, beta_2=0.999)
# use bce loss function for binary classification 
model1_2.compile(optimizer=nad_opt, loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model 
predictions1_2 = model1_2.fit(X_train,
                    y_train,
                    epochs=100,
                    callbacks=[es_callback],
                    batch_size=10,
                    )
# Out:
# Epoch 1/100
# 4558/4558 [==============================] - 39s 9ms/step - loss: 0.4717 - accuracy: 0.8945
# Epoch 2/100
# 4558/4558 [==============================] - 39s 8ms/step - loss: 0.1449 - accuracy: 0.9853
# Epoch 3/100
# 4558/4558 [==============================] - 38s 8ms/step - loss: 0.1036 - accuracy: 0.9923
# Epoch 4/100
# 4558/4558 [==============================] - 39s 9ms/step - loss: 0.0970 - accuracy: 0.9910
# Epoch 5/100
# 4558/4558 [==============================] - 39s 9ms/step - loss: 0.0982 - accuracy: 0.9864
# Epoch 6/100
# 4558/4558 [==============================] - 38s 8ms/step - loss: 0.0841 - accuracy: 0.9908
# Epoch 7/100
# 4558/4558 [==============================] - 39s 9ms/step - loss: 0.0837 - accuracy: 0.9890
# Epoch 8/100
# 4558/4558 [==============================] - 39s 9ms/step - loss: 0.0680 - accuracy: 0.9908
# Epoch 9/100
# 4558/4558 [==============================] - 39s 8ms/step - loss: 0.0556 - accuracy: 0.9958
# Epoch 10/100
# 4558/4558 [==============================] - 39s 9ms/step - loss: 0.0594 - accuracy: 0.9925
# Epoch 11/100
# 4250/4558 [==========================>...] - ETA: 2s - loss: 0.0569 - accuracy: 0.9922

# %%
model1.summary()

# %%
m1_dict2 =  predictions1_2.history
m1_dict2.keys()

# %%
acc_loss_plot(m1_dict2)

# %%
# Print the loss and accuracy for the test set 
results_test = model1_2.evaluate(X_test, y_test)
results_test

# %%
# predict probabilities for test set
yhat_probs = model1_2.predict(X_test, verbose=0)
# predict crisp classes for test set
yhat_classes = model1_2.predict_classes(X_test, verbose=0)

# reduce to 1d array
yhat_probs = yhat_probs[:, 0]
yhat_classes = yhat_classes[:, 0]

# %%
# assess metrics of model

# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(y_test, yhat_classes)
print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp)
precision = precision_score(y_test, yhat_classes)
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(y_test, yhat_classes)
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_test, yhat_classes)
print('F1 score: %f' % f1)
# kappa
kappa = cohen_kappa_score(y_test, yhat_classes)
print('Cohens kappa: %f' % kappa)
# ROC AUC
auc = roc_auc_score(y_test, yhat_probs)
print('ROC AUC: %f' % auc)
# confusion matrix
matrix = confusion_matrix(y_test, yhat_classes)
print(matrix)

# %% [markdown]
# ## nn_model #2

# %%
# create sequential model
model2 = models.Sequential()

# sigmoid activation layer 
model2.add(layers.Dense(200, input_dim=count_terms, activation='tanh', 
                       kernel_initializer=initializer, 
                   ))
# add relu activated hidden layers
model.add(layers.Dense(200, activation='relu', 
                       kernel_initializer=initializer,))   


# output layer with sigmoid activation for binary target
model2.add(layers.Dense(1, activation='sigmoid'))

# %%
# Compile the model
# early stopping to prevent overfitting
es_callback = keras.callbacks.EarlyStopping(monitor='loss', patience=10)
#define optimizer and learningrate

# use bce loss function for binary classification 
model2.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model 
history2 = model2.fit(X_train,
                    y_train,
                    epochs=100,
                    callbacks=[es_callback],
                    batch_size=72,
                    )

# %%
model2.summary()

# %%
model2_dict = history1.history
model2_dict.keys()

# %%
acc_loss_plot(model2_dict)

# %%
# Print the loss and accuracy for the training set 
model2.evaluate(X_train, y_train)

# %%
# Print the loss and accuracy for the test set 
results_test = model2.evaluate(X_test, y_test)
results_test

# %%
# predict probabilities for test set
yhat_probs = model2.predict(X_test, verbose=0)
# predict crisp classes for test set
yhat_classes = model2.predict_classes(X_test, verbose=0)

# reduce to 1d array
yhat_probs = yhat_probs[:, 0]
yhat_classes = yhat_classes[:, 0]

# %%
# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(y_test, yhat_classes)
print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp)
precision = precision_score(y_test, yhat_classes)
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(y_test, yhat_classes)
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_test, yhat_classes)
print('F1 score: %f' % f1)
# kappa
kappa = cohen_kappa_score(y_test, yhat_classes)
print('Cohens kappa: %f' % kappa)
# ROC AUC
auc = roc_auc_score(y_test, yhat_probs)
print('ROC AUC: %f' % auc)
# confusion matrix
matrix = confusion_matrix(y_test, yhat_classes)
print(matrix)

# %% [markdown]
# from sklearn.model_selection import StratifiedKFold
# # define 3 fold cross validation test harness
# kfold = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
# cvscores = []
# for train, test in kfold.split(X, y):
#   # which model used
#     to_model = model
#    # Compile model
#     to_model.compile(optimizer=opt, loss="binary_crossentropy", metrics=['accuracy'],)
#     # Fit the model
#     to_model.fit(X[train], y[train], epochs=400, batch_size=10, callbacks=[es_callback])
#     # evaluate the model
#     scores = to_model.evaluate(X[test], y[test])
#     print("%s: %.2f%%" % (to_model.metrics_names[1], scores[1]*100))
#     cvscores.append(scores[1] * 100)
# print("%.2f%% (+/- %.2f%%)" % (np.mean(cvscores), np.std(cvscores)))

# %% [markdown]
# ## nn model 3

# %%
# create sequential model
model3 = models.Sequential()
# Initialize a sequential model with same size dense layers to compare to pyramid style layer structure

# activation layer 
model3.add(layers.Dense(200, input_dim=count_terms, activation='relu', kernel_initializer=initializer2))
#batch normalization layer
#model2.add(layers.BatchNormalization())
# relu activated hidden layer
model3.add(layers.Dense(120, ))

model3.add(layers.Dense(11, ))
# output layer with sigmoid activation for binary target
model3.add(layers.Dense(1, activation='sigmoid'))

# %%
# compile model
model3.compile(optimizer=nad_opt, loss="binary_crossentropy", metrics=['accuracy'])

# %%
# Train the model 
predictions3 = model3.fit(X_train,
                    y_train,
                    epochs=500,
                    callbacks=[es_callback],
                    batch_size=72,
                    
                    )

# %%
model3_dict = history2.history
model3_dict.keys()

# %%
acc_loss_plot(model3_dict)

# %%
# Print the loss and accuracy for the training set 
model3.evaluate(X_train, y_train)

# %%
# Output (probability) predictions for the train set 
y_hat_train = model3.predict(X_train)

# %%
# Print the loss and accuracy for the test set 
results_test = model3.evaluate(X_test, y_test)
results_test

# %%
# predict probabilities for test set
yhat_probs = model3.predict(X_test, verbose=0)
# predict crisp classes for test set
yhat_classes = model3.predict_classes(X_test, verbose=0)

# reduce to 1d array
yhat_probs = yhat_probs[:, 0]
yhat_classes = yhat_classes[:, 0]

# %%
# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(y_test, yhat_classes)
print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp)
precision = precision_score(y_test, yhat_classes)
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(y_test, yhat_classes)
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_test, yhat_classes)
print('F1 score: %f' % f1)
# kappa
kappa = cohen_kappa_score(y_test, yhat_classes)
print('Cohens kappa: %f' % kappa)
# ROC AUC
auc = roc_auc_score(y_test, yhat_probs)
print('ROC AUC: %f' % auc)
# confusion matrix
matrix = confusion_matrix(y_test, yhat_classes)
print(matrix)

# %% [markdown]
# # nn model no SMOTE, use weights

# %%
# split data 
X3_train, X3_test, y3_train, y3_test = train_test_split(X, y, random_state=42,
                                                     test_size=.2, stratify=y)
# build TFIDF features on tweet with

tfv = TfidfVectorizer(min_df=0.0, max_df=1.0, ngram_range=(1,2), use_idf=True
                     )
X_train_trans = tfv.fit_transform(X3_train)
xdf = pd.DataFrame(X_train_trans[0].T.todense(),
index=tfv.get_feature_names(), columns=["term"])
xdf = xdf.sort_values('term', ascending=False)
print (xdf.head(25))

test_features = tfv.transform(X3_test)
X3_train = X_train_trans.copy()
X3_test = test_features.copy()

# %%
# verify shape of data
print('Test label shape:', np.shape(y3_test))
print('Train label shape:', np.shape(y3_train))
print('Test shape:', np.shape(X3_test))
print('Train shape:', np.shape(X3_train))
#assign variable to np.shape tuple, width dimension
input_dimension = np.shape(X_train)
count_terms = input_dimension[1]

# %%
# get class weights for use in model in lieu of smote
from sklearn.utils import class_weight
class_weights = class_weight.compute_class_weight('balanced', np.unique(y3_train), y3_train)

print(class_weights)

# %% [markdown]
# # create sequential model
# model4 = models.Sequential()
# model4.add(layers.BatchNormalization())
# #model5.add(layers.Dropout(0.3))
# # sigmoid activation layer
# model4.add(layers.Dense(300, input_dim=5056, activation='tanh', ))
# model4.add(layers.BatchNormalization())
# model4.add(layers.Dropout(0.2))
# model4.add(layers.Dense(150, activation='relu'))
#
# #model.add(layers.BatchNormalization())
# #model.add(layers.Dense(160, activation='relu'))
#
# #model5.add(layers.Dropout(0.2))
# model4.add(layers.Dense(10, activation='selu'))
# model4.add(layers.BatchNormalization())
# # output layer with sigmoid activation for binary target
# model4.add(layers.Dense(2, activation='softmax'))

# %%
#define optimizer and learningrate
lr = (0.0001)
opt = optimizers.SGD(lr=lr)
#compile model
model.compile(optimizer=opt, loss="binary_crossentropy", metrics=['accuracy'])

# %%
# Train the model 
history4 = model.fit(X3_train,
                    y3_train,
                    epochs=1000,
                    callbacks=[es_callback],
                    batch_size=32,
                    class_weight={1:3.13, 0:0.60}
                    
                    )

# %%
model.summary()

# %%
model4_dict = history4.history
model4_dict.keys()

# %%
acc_loss_plot(model4_dict)

# %%
# Print the loss and accuracy for the training set 
model.evaluate(X3_train, y3_train)

# %%
# Output (probability) predictions for the train set 
y_hat_train = model.predict(X3_train)

# %%
# Print the loss and accuracy for the test set 
results_test = model.evaluate(X3_test, y3_test)
results_test

# %%
# Output (probability) predictions for the validation set 
y_hat_test = model4.predict(X3_test) 
y_hat_test

# %% [markdown]
# ## model and assess using statistical methods

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import ComplementNB, BernoulliNB

# %%
# the models that you want to compare
stat_models = {
    'clf_randforest': RandomForestClassifier(),
    'clf_knn': KNeighborsClassifier(),
    'clf_dt' : DecisionTreeClassifier(),

 
}

# the optimisation parameters for each of the above models
params = {
    'clf_randforest': {
        'n_jobs': [-1],
        'class_weight': ['balanced'],
        'criterion': ['gini', 'entropy']
    },
    'clf_knn': {
        'weights': ['distance'],
        'algorithm': ['ball_tree', 'kd_tree', 'brute']
         },
    
    'clf_dt' : {
        'criterion': ['gini', 'entropy'],
        'min_samples_split': [2, 5, 10],
        'random_state':[42]
         },
                         
                         }

# %%
def fit_search(X_data, y_data):
        """
        fits the list of models to the training data, thereby obtaining in each 
        case an evaluation score after GridSearchCV cross-validation
        """
        for name in stat_models.keys():
            est = stat_models[name]
            est_params = params[name]
            gscv = GridSearchCV(estimator=est, param_grid=est_params, cv=10)
            gscv.fit(X_data, y_data)
            print("best parameters are: {}".format(gscv.best_estimator_))
            y_pred = gscv.predict(X_data)
            print(classification_report(y_data, y_pred))
            # Generate confusion matrix
            matrix = plot_confusion_matrix(gscv.best_estimator_, X_test, y_test,
                                 cmap=plt.cm.Blues,
                                 normalize='true')
            plt.title('Confusion matrix for our classifier')
            plt.show(matrix)
            plt.show()

# %%
# summarize the new class distribution
counter = Counter(y_train)
print(counter)
# verify shape of data
print('Test label shape:', np.shape(y_test))
print('Train label shape:', np.shape(y_train))
print('Test shape:', np.shape(X_test))
print('Train shape:', np.shape(X_train))

# %%
import warnings
warnings.filterwarnings('ignore') 
fit_search(X_train, y_train)

# %%
def main(X, y, clf):
        
    #X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y, test_size=.3,)

    pipeline = Pipeline([
       
        ('clf', clf())
    ])

    # train classifier
    pipeline.fit(X_train, y_train.ravel())

    # predict on test data
    y_pred = pipeline.predict(X_test)

    # display results
    display_results(y_test, y_pred)

# %%
def display_results(y_test, y_pred):
    labels = np.unique(y_pred)
    confusion_mat = confusion_matrix(y_test, y_pred, labels=labels)
    accuracy = (y_pred == y_test).mean()

    print("Labels:", labels)
    print("Confusion Matrix:\n", confusion_mat)
    print("Accuracy:", accuracy)

# %%
# Generate confusion matrix
matrix = plot_confusion_matrix(y_test, y_hat_classes,
                                 cmap=plt.cm.Blues,
                                 normalize='true')
plt.title('Confusion matrix for our classifier')
plt.show(matrix)
plt.show()

# %%
main(X_train, y_train, RandomForestClassifier(class_weight='balanced', n_jobs=-1))

# %%
main(X_train, y_train, ComplementNB(alpha=1.0, fit_prior=True, class_count=2, norm=False))

# %%
main(X_train, y_train, clf=KNeighborsClassifier(algorithm='ball_tree', weights='distance'))

# %%
main(X_train, y_train, DecisionTreeClassifier(criterion='entropy', max_depth=50))

# %%
main(X_train, y_train, BernoulliNB)

# %% [markdown]
# # word2vec

# %%
import gensim

# %%
wvmodel = gensim.models.Word2Vec (df.tokenl, size=150, min_count=1, 
                                 )
vocab = list(wvmodel.wv.vocab)
Xwv = wvmodel[wvmodel.wv.vocab]
df_wv =pd.DataFrame(Xwv)
df_wv.shape
df_wv.head()

# %%
df_wv.shape

# %%
from sklearn.decomposition import IncrementalPCA    # inital reduction
from sklearn.manifold import TSNE                   # final reduction      
import plotly


def reduce_dimensions(model):
    num_dimensions = 2  # final num dimensions (2D, 3D, etc)

    vectors = [] # positions in vector space
    labels = [] # keep track of words to label our data again later
    for word in model.wv.vocab:
        vectors.append(model.wv[word])
        labels.append(word)

    # convert both lists into numpy vectors for reduction
    vectors = np.asarray(vectors)
    labels = np.asarray(labels)

    # reduce using t-SNE
    vectors = np.asarray(vectors)
    tsne = TSNE(n_components=num_dimensions, random_state=42)
    vectors = tsne.fit_transform(vectors)

    x_vals = [v[0] for v in vectors]
    y_vals = [v[1] for v in vectors]
    return x_vals, y_vals, labels

def plot_with_plotly(x_vals, y_vals, labels, plot_in_notebook=True, ):
    from plotly.offline import init_notebook_mode, iplot, plot
    import plotly.graph_objs as go

    trace = go.Scatter(x=x_vals, y=y_vals, mode='text', text=labels,)
    data = [trace]

    if plot_in_notebook:
        init_notebook_mode(connected=True)
        iplot(data, filename='word-embedding-plot')
    else:
        plot(data, filename='word-embedding-plot.html')

# %%
x_vals, y_vals, labels = reduce_dimensions(wvmodel)

# %%
plot_with_plotly(x_vals, y_vals, labels)

# %% [markdown]
# # hashtag frequency analysis

# %%
hash_list = data['hashtags'].to_list()

flat_hash = [i for j in hash_list for i in j]

hash_freqdist = FreqDist(flat_hash)
hash_25 = dict(hash_freqdist.most_common(25))
hash_list1 = list(hash_25.keys())
hash_list1

# %%
hash_df = data.copy()
hash_df = hash_df[hash_df['sentiment'].isin(['positive', 'negative']) ]
col = ['hashtags', 'sentiment']
hash_df = hash_df[col]
hash_df['hashtags'] = ([detokenizer.detokenize(ht) for ht in hash_df.hashtags])

hash_df.head()

# %%
hash_df2 = hash_df.hashtags.str.split(' ').apply(pd.Series)
hash_df2.index = hash_df.set_index(['hashtags', 'sentiment']).index
hash_df2=hash_df2.stack().reset_index(['hashtags', 'sentiment'])

# %%
hash_df2

# %%
hash_df2.drop(['hashtags'], axis=1, inplace=True)

# %%
hash_df2.rename( columns={0 :'hashtag'}, inplace=True )

# %%
hash_df2.reset_index(drop=True, inplace=True)

# %%
hash_df2.mask = [hash_df2['hashtag'].isin(hash_list1)]

# %%
hash_df2.index = hash_df2.mask

# %%
hash_df2.rename(columns={ hash_df2.columns[1]: "hashtags" }, inplace = True)

# %%
hash_df2.shape

# %%
hash_df2['hashbool'] = hash_df2.index.copy()
hash_df2['hashbool'] = hash_df2['hashbool'].astype(str)
for x in hash_df2['hashbool']:
    hash_df2['hashbool'] = hash_df2['hashbool'].str.replace(r'[^a-zA-Z]', "")

# %%
hash_df = hash_df2.loc[hash_df2['hashbool']=='True']

# %%
fig, ax = plt.subplots(figsize=(40,30))
x = hash_df['hashtags']
hue = hash_df['sentiment']
ax = sns.countplot(x, hue=hue, data=data)
plt.title('Top #Hashtags', fontsize=40)
plt.xlabel('#Hashtag', fontsize=25)
plt.ylabel('Count', fontsize=25)
plt.xticks(fontsize=20, rotation=45)

# %%
hash_df = data.copy()
hash_df = hash_df[hash_df['sentiment'].isin(['positive', 'negative']) ]
hash_model = gensim.models.Word2Vec (hash_df.hashtags, size=50, min_count=1, 
                                 )
hash_vocab = list(hash_model.wv.vocab)
hash_x = hash_model[hash_model.wv.vocab]
df_h =pd.DataFrame(hash_x)
df_h.shape
df_h.head()

# %%
x_vals, y_vals, labels = reduce_dimensions(hash_model)

# %%
plot_with_plotly(x_vals, y_vals, labels)

# %% [markdown]
# ## create dataframe with tweets containing "rt" for retweet assessment later

# %%
# for possible assessment later
df_rt = data[data['clean_tweet'].str.contains("rt")]

# %%
df_rt.describe()

# %% [markdown]
# # Final Model
